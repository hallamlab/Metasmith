# %% [markdown]
# # Data Types

# %%
from pathlib import Path
from metasmith.python_api import *

# %%
source = HttpSource.Parse("https://raw.githubusercontent.com/hallamlab/Metasmith/release/lib/data_types/hallamlab.yml").AsSource()
source
# Out:
# Source(address='https://raw.githubusercontent.com/hallamlab/Metasmith/release/lib/data_types/hallamlab.yml', type=SourceType.HTTP)

# %%
dtypes = DataTypeLibrary.Load(source)
for name in dtypes.types:
    print(name)
# Out:
# contigs
# oci_image_diamond
# oci_image_pprodigal
# orf_annotations
# orfs_faa
# protein_reference_diamond

# %%
agent = Agent(
    home = Source.FromLocal(Path("./metasmith_home").resolve()),
)
agent
# Out:
# Agent(home=Source(address='/home/tony/workspace/tools/Metasmith/docs/source/metasmith_home', type=SourceType.DIRECT), setup_commands=[], container='docker://quay.io/hallamlab/metasmith:latest', globus_uuid=None)

# %%
agent.GenerateWorkflow(
    
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 agent.GenerateWorkflow(
#       2
#       3 )
#
# TypeError: Agent.GenerateWorkflow() missing 3 required positional arguments: 'given', 'transforms', and 'targets'
