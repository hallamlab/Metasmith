# %%
import requests
import json

# %%
url = "http://localhost:56100/api/v1/sbatch"
requests.post(url, json={"command": "echo 'Hello, World!'"})

# %%
url = "http://localhost:56100/api/v1/handle_sbatch"
res = requests.get(url)
print(json.dumps([f"{a}:{b}" for a, b in res.json()], indent=4))
