# %%
from metasmith.python_api import TransformInstanceLibrary

transforms = TransformInstanceLibrary("./cache/transforms")

# %%
from metasmith import examples
dtypes = examples.DataTypeLibraries("minimal_genomics")
transforms.AddTypeLibrary("genomics", dtypes)
# Out:
# DataTypeLibrary(schema='1.0', ontology=DataTypeOntology(name='EDAM', version=1.25, doi='https://doi.org/10.1093/bioinformatics/btt113', strict=False), types={'aa_sequences': <{data:Amino acid sequence,format:FASTA}:oF3YSVYQ>, 'contigs': <{data:DNA sequence,format:FASTA}:4M4PqXwA>, 'oci_image_diamond': <{data:software container,format:OCI,provides:diamond}:iGL288Xm>, 'oci_image_pprodigal': <{data:software container,format:OCI,provides:pprodigal}:90LdbjQO>, 'orf_annotations': <{data:Protein features,format:CSV}:kImyYZjD>, 'protein_reference_fasta': <{data:database reference,format:.faa}:fK7OFWQt>, 'protein_reference_diamond': <{data:database reference,format:.dmnd}:VpPqsgy1>})

# %%
transforms.AddStub("prodigal")
transforms.AddStub("blast")
transforms.Save()
