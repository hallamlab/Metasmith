# %% [markdown]
# # Quickstart

# %%
from pathlib import Path
from metasmith.python_api import *
from metasmith import examples

# %%
dtypes, contigs, references, transforms = examples.GenomicsAnnotation()
for x in [dtypes, contigs, references, transforms]:
    print(type(x))
# Out:
# <class 'metasmith.models.libraries.DataTypeLibrary'>
# <class 'metasmith.models.libraries.DataInstanceLibrary'>
# <class 'metasmith.models.libraries.DataInstanceLibrary'>
# <class 'metasmith.models.libraries.TransformInstanceLibrary'>

# %%
path_to_agent_home = Path("./metasmith_home").resolve()
agent = Agent(
    home = Source.FromLocal(path_to_agent_home),
)
agent.Deploy()
# Out:
# 2025-03-19_00-51-05  | >>> AGENT_HOME=/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home
# 2025-03-19_00-51-05  | >>> mkdir -p $AGENT_HOME
# 2025-03-19_00-51-05  | >>> mkdir -p /home/tony/.globus
# 2025-03-19_00-51-05  | >>> mkdir -p /home/tony/.globusonline
# 2025-03-19_00-51-06  | >>> {if not exists}: apptainer pull/metasmith.sif docker://quay.io/hallamlab/metasmith:latest
# 2025-03-19_00-51-07  | staged [msm_stub]
# 2025-03-19_00-51-07  | staged [msm]
# 2025-03-19_00-51-07  | >>> cd /home/tony/workspace/tools/Metasmith/main/docs/metasmith_home && ./msm api deploy_from_container
# 2025-03-19_00-51-07 E| FATAL:   While checking container encryption: could not open image /home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/metasmith.sif: failed to retrieve path for /home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/metasmith.sif: lstat /home/tony/workspace/tools/Metasmith/docs/workspace: no such file or directory
# 2025-03-19_00-51-08  | staged [lib/agent.yml]
# 2025-03-19_00-51-08  | staged [lib/msm_bootstrap]
# 2025-03-19_00-51-08  | staged [lib/nextflow_config]
# 2025-03-19_00-51-08  | deploying [5] staged files
# 2025-03-19_00-51-08  | deployed to [/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home]

# %%
task = agent.GenerateWorkflow(
    given=[contigs, references],
    transforms=[transforms],
    targets=[
        dtypes["orf_annotations"].WithLineage([dtypes["contigs"]]),
    ]
)
# for step in task.plan.steps:
#     print(f"step {step.order}: {step.transform.name}")
#     print(f"    uses: {[str(x.path) for x in step.uses]}")
#     print(f"   makes: {[str(x.path) for x in step.produces]}")
#     print()

[step.transform.name for step in task.plan.steps]
# Out:
# ['pprodigal', 'make_diamond_db', 'diamond']

# %%
agent.StageWorkflow(task, on_exist="clear")
# Out:
# 2025-03-18_22-43-37  | connecting to deployed agent
# 2025-03-18_22-43-38  | starting relay service
#  | > 2025-03-18_22-43-38  | connecting to relay as [M25gFoDSvEG5]
# E| > 2025-03-18_22-43-38 E| relay server already running in [relay/connections]
# 2025-03-18_22-43-40 W| task already staged at [/home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/runs/YCrDVqm3]
# 2025-03-18_22-43-40 W| clearing previously staged task
# 2025-03-18_22-43-42  | sending metadata for workflow [YCrDVqm3]
# 2025-03-18_22-43-44  | staging
#  | > including dev binds
#  | > 2025-03-18_22-43-45  | api call to [stage_workflow] with [{'task_key': 'YCrDVqm3'}]
#  | > 2025-03-18_22-43-45  | staging workflow [YCrDVqm3] with [2] data libs and [1] transform libs
#  | > 2025-03-18_22-43-45  | ex| /home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home
#  | > 2025-03-18_22-43-46  | work [/ws/runs/YCrDVqm3]
#  | > 2025-03-18_22-43-46  | data [/msm_home/data]
#  | > 2025-03-18_22-43-46  | external work [/home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/runs/YCrDVqm3]
#  | > 2025-03-18_22-43-46  | external data [/home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/data]
#  | > 2025-03-18_22-43-46  | moving remote data libraries to [/msm_home/data]
#  | > 2025-03-18_22-43-46  | using nextflow preset [default]
#  | > 2025-03-18_22-43-46  | [YCrDVqm3] staged to [{AGENT_HOME}/runs/YCrDVqm3]
# 2025-03-18_22-43-47  | closing connection

# %%
agent.RunWorkflow(task)
# Out:
# 2025-03-18_22-43-47  | connecting to deployed agent
# 2025-03-18_22-43-48  | starting relay service
#  | > 2025-03-18_22-43-48  | connecting to relay as [yRH4qxCNFq3O]
# E| > 2025-03-18_22-43-48 E| relay server already running in [relay/connections]
# 2025-03-18_22-43-50  | executing workflow
# 2025-03-18_22-43-52  | closing connection

# %%
agent.CheckWorkflow(task)
# Out:
# 2025-03-18_22-44-19  | connecting to deployed agent
# 2025-03-18_22-44-20  | starting relay service
# E| > 2025-03-18_22-44-21 E| relay server already running in [relay/connections]
#  | > 2025-03-18_22-44-21  | connecting to relay as [1L6JCeu34ssK]
#  | > including dev binds
#  | > 2025-03-18_22-44-22  | api call to [check_workflow] with [{'key': 'YCrDVqm3'}]
#  | > 2025-03-18_22-44-22  | searching for logs
#  | > 2025-03-18_22-44-22  | found [1] runs
#  | > 2025-03-18_22-44-22  |     1: [logs.2025-03-18_22-43-51]
#  | > 2025-03-18_22-44-22  | here is the main log of the latest run [logs.2025-03-18_22-43-51]
#  | > 2025-03-18_22-44-22  | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#  | > 2025-03-18_22-44-22  |
#  | > including dev binds
#  | > 2025-03-18_22-43-51  | api call to [run_workflow] with [{'key': 'YCrDVqm3', 'log_dir': '_metasmith/logs.2025-03-18_22-43-51'}]
#  | > 2025-03-18_22-43-52  | start time [2025-03-18_22-43-52]
#  | > 2025-03-18_22-43-52  | running workflow [YCrDVqm3] with preset [default]
#  | > 2025-03-18_22-43-52  | loading agent metadata
#  | > 2025-03-18_22-43-52  | workspace [/msm_home/runs/YCrDVqm3]
#  | > 2025-03-18_22-43-52  | external workspace [/home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/runs/YCrDVqm3]
#  | > 2025-03-18_22-43-52  | preset [default]
#  | > 2025-03-18_22-43-52  | steps [3]
#  | > 2025-03-18_22-43-52  | locating input data with personal globus endpoint
#  | > 2025-03-18_22-43-52  | [58skwW47C2Kc] is at [/msm_home/runs/YCrDVqm3/_metasmith/task/transforms/58skwW47C2Kc]
#  | > 2025-03-18_22-43-52  | [nSyCz0z7myGP] is at [/msm_home/runs/YCrDVqm3/_metasmith/task/data/nSyCz0z7myGP]
#  | > 2025-03-18_22-43-52  | [MKgg3Qk6hzLl] is at [/msm_home/runs/YCrDVqm3/_metasmith/task/data/MKgg3Qk6hzLl]
#  | > 2025-03-18_22-43-52  | calling nextflow from container
#  | > 2025-03-18_22-43-54  |  N E X T F L O W   ~  version 24.10.5
#  | > 2025-03-18_22-43-54  |
#  | > 2025-03-18_22-43-54  | WARN: It appears you have never run this project before -- Option `-resume` is ignored
#  | > 2025-03-18_22-43-54  | Launching `./workflow.nf` [voluminous_kilby] DSL2 - revision: db48bd1343
#  | > 2025-03-18_22-43-54  |
#  | > 2025-03-18_22-43-56  | [-        ] pprodigal__z0wbXaiv       -
#  | > 2025-03-18_22-43-56  | [-        ] make_diamond_db__7NMHuXxn -
#  | > 2025-03-18_22-43-56  | [-        ] diamond__C1D0jqnx         -
#  | > 2025-03-18_22-43-56  |
#  | > 2025-03-18_22-43-56  | executor >  local (2)
#  | > 2025-03-18_22-43-56  | [28/5a832e] pprodigal__z0wbXaiv (1)       | 0 of 1
#  | > 2025-03-18_22-43-56  | [a6/3549f3] make_diamond_db__7NMHuXxn (1) | 0 of 1
#  | > 2025-03-18_22-43-56  | [-        ] diamond__C1D0jqnx             -
#  | > 2025-03-18_22-44-02  |
#  | > 2025-03-18_22-44-02  | executor >  local (2)
#  | > 2025-03-18_22-44-02  | [28/5a832e] pprodigal__z0wbXaiv (1)       | 0 of 1
#  | > 2025-03-18_22-44-02  | [a6/3549f3] make_diamond_db__7NMHuXxn (1) | 1 of 1 ✔
#  | > 2025-03-18_22-44-02  | [-        ] diamond__C1D0jqnx             -
#  | > 2025-03-18_22-44-03  |
#  | > 2025-03-18_22-44-03  | executor >  local (3)
#  | > 2025-03-18_22-44-03  | [28/5a832e] pprodigal__z0wbXaiv (1)       | 1 of 1 ✔
#  | > 2025-03-18_22-44-03  | [a6/3549f3] make_diamond_db__7NMHuXxn (1) | 1 of 1 ✔
#  | > 2025-03-18_22-44-03  | [a5/ab6933] diamond__C1D0jqnx (1)         | 0 of 1
#  | > 2025-03-18_22-44-11  |
#  | > 2025-03-18_22-44-11  | executor >  local (3)
#  | > 2025-03-18_22-44-11  | [28/5a832e] pprodigal__z0wbXaiv (1)       | 1 of 1 ✔
#  | > 2025-03-18_22-44-11  | [a6/3549f3] make_diamond_db__7NMHuXxn (1) | 1 of 1 ✔
#  | > 2025-03-18_22-44-11  | [a5/ab6933] diamond__C1D0jqnx (1)         | 1 of 1 ✔
#  | > 2025-03-18_22-44-11  |
#  | > 2025-03-18_22-44-11  | executor >  local (3)
#  | > 2025-03-18_22-44-11  | [28/5a832e] pprodigal__z0wbXaiv (1)       | 1 of 1 ✔
#  | > 2025-03-18_22-44-11  | [a6/3549f3] make_diamond_db__7NMHuXxn (1) | 1 of 1 ✔
#  | > 2025-03-18_22-44-11  | [a5/ab6933] diamond__C1D0jqnx (1)         | 1 of 1 ✔
#  | > 2025-03-18_22-44-12  | compiling results
#  | > 2025-03-18_22-44-12  | results for [YCrDVqm3] at [/home/tony/workspace/tools/Metasmith/docs/workspace/metasmith_home/runs/YCrDVqm3/results]
#  | > 2025-03-18_22-44-12  | gathering log files
#  | > 2025-03-18_22-44-12  | run completed at [2025-03-18_22-44-12]
#  | > 2025-03-18_22-44-22  |
#  | > 2025-03-18_22-44-22  | <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  | > 2025-03-18_22-44-22  | log folder at [/msm_home/runs/YCrDVqm3/_metasmith/logs.2025-03-18_22-43-51]
# 2025-03-18_22-44-24  | closing connection
