# %% [markdown]
# # Quickstart

# %%
from pathlib import Path
from metasmith.python_api import *
from metasmith import examples

# %%
dtypes, contigs, references, transforms = examples.GenomicsAnnotation()
for x in [dtypes, contigs, references, transforms]:
    print(type(x))
# Out:
# <class 'metasmith.models.libraries.DataTypeLibrary'>
# <class 'metasmith.models.libraries.DataInstanceLibrary'>
# <class 'metasmith.models.libraries.DataInstanceLibrary'>
# <class 'metasmith.models.libraries.TransformInstanceLibrary'>

# %%
for x, d in contigs.manifest.items():
    s = 20-len(str(x))
    print(f"{x}{' '*s}({d})")
# Out:
# fosmid.fna          (genomics::contigs)

# %%
for x, d in references.manifest.items():
    s = 20-len(str(x))
    print(f"{x}{' '*s}({d})")
# Out:
# blast.oci.uri       (genomics::oci_image_blast)
# prodigal.oci.uri    (genomics::oci_image_prodigal)
# swissprot_bcaa.faa  (genomics::protein_reference_fasta)

# %%
for x in transforms.manifest:
    print(x.stem)
# Out:
# blast
# prodigal

# %%
path_to_agent_home = Path("./metasmith_home").resolve()
agent = Agent(
    home = Source.FromLocal(path_to_agent_home),
)
# agent.Deploy()

# %%
task = agent.GenerateWorkflow(
    given=[contigs, references],
    transforms=[transforms],
    targets=[
        dtypes["orf_annotations"].WithLineage([dtypes["contigs"]]),
    ]
)
for step in task.plan.steps:
    print(f"step {step.order}: {step.transform.name}")
    print(f"    uses: {[str(x.path) for x in step.uses]}")
    print(f"   makes: {[str(x.path) for x in step.produces]}")
    print()

# [step.transform.name for step in task.plan.steps]
# Out:
# step 1: prodigal
#     uses: ['fosmid.fna', 'prodigal.oci.uri']
#    makes: ['orfs.faa']
#
# step 2: blast
#     uses: ['orfs.faa', 'swissprot_bcaa.faa', 'blast.oci.uri']
#    makes: ['annotations.csv']

# %%
agent.StageWorkflow(task, on_exist="clear")
# agent.StageWorkflow(task, on_exist="update")
# Out:
# 2025-03-20_22-53-05  | connecting to deployed agent
# 2025-03-20_22-53-07  | starting relay service
# E| > 2025-03-20_22-53-07 E| relay server already running in [relay/connections]
#  | > 2025-03-20_22-53-07  | connecting to relay as [OlNHUL6WAIuC]
# 2025-03-20_22-53-09 W| task already staged at [/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home/runs/BxuRVhUf]
# 2025-03-20_22-53-09 W| clearing previously staged task
# 2025-03-20_22-53-10  | sending metadata for workflow [BxuRVhUf]
# 2025-03-20_22-53-13  | staging
#  | > including dev binds
#  | > 2025-03-20_22-53-13  | api call to [stage_workflow] with [{'task_key': 'BxuRVhUf'}]
#  | > 2025-03-20_22-53-13  | staging workflow [BxuRVhUf] with [2] data libs and [1] transform libs
#  | > 2025-03-20_22-53-13  | ex| /home/tony/workspace/tools/Metasmith/main/docs/metasmith_home
#  | > 2025-03-20_22-53-14  | work [/ws/runs/BxuRVhUf]
#  | > 2025-03-20_22-53-14  | data [/msm_home/data]
#  | > 2025-03-20_22-53-14  | external work [/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home/runs/BxuRVhUf]
#  | > 2025-03-20_22-53-14  | external data [/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home/data]
#  | > 2025-03-20_22-53-14  | moving remote data libraries to [/msm_home/data]
#  | > 2025-03-20_22-53-14  | using nextflow preset [default]
#  | > 2025-03-20_22-53-14  | [BxuRVhUf] staged to [{AGENT_HOME}/runs/BxuRVhUf]
# 2025-03-20_22-53-15  | closing connection

# %%
agent.RunWorkflow(task)
# Out:
# 2025-03-20_22-53-15  | connecting to deployed agent
# 2025-03-20_22-53-16  | starting relay service
#  | > 2025-03-20_22-53-16  | connecting to relay as [dItSKiPAd4Tu]
# E| > 2025-03-20_22-53-16 E| relay server already running in [relay/connections]
# 2025-03-20_22-53-18  | executing workflow
# 2025-03-20_22-53-20  | closing connection

# %%
agent.CheckWorkflow(task)
# Out:
# 2025-03-20_22-53-20  | connecting to deployed agent
# 2025-03-20_22-53-21  | starting relay service
#  | > 2025-03-20_22-53-22  | connecting to relay as [3jl3l0v4tvWu]
# E| > 2025-03-20_22-53-22 E| relay server already running in [relay/connections]
#  | > including dev binds
#  | > 2025-03-20_22-53-24  | api call to [check_workflow] with [{'key': 'BxuRVhUf'}]
#  | > 2025-03-20_22-53-24  | searching for logs
#  | > 2025-03-20_22-53-24  | found [1] runs
#  | > 2025-03-20_22-53-24  |     1: [logs.2025-03-20_22-53-19]
#  | > 2025-03-20_22-53-24  | here is the main log of the latest run [logs.2025-03-20_22-53-19]
#  | > 2025-03-20_22-53-24  | >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#  | > 2025-03-20_22-53-24  |
#  | > including dev binds
#  | > 2025-03-20_22-53-19  | api call to [run_workflow] with [{'key': 'BxuRVhUf', 'log_dir': '_metasmith/logs.2025-03-20_22-53-19'}]
#  | > 2025-03-20_22-53-19  | start time [2025-03-20_22-53-19]
#  | > 2025-03-20_22-53-19  | running workflow [BxuRVhUf] with preset [default]
#  | > 2025-03-20_22-53-19  | loading agent metadata
#  | > 2025-03-20_22-53-19  | workspace [/msm_home/runs/BxuRVhUf]
#  | > 2025-03-20_22-53-19  | external workspace [/home/tony/workspace/tools/Metasmith/main/docs/metasmith_home/runs/BxuRVhUf]
#  | > 2025-03-20_22-53-19  | preset [default]
#  | > 2025-03-20_22-53-19  | steps [2]
#  | > 2025-03-20_22-53-19  | locating input data with personal globus endpoint
#  | > 2025-03-20_22-53-19  | [bzoYw5jlQsSh] is at [/msm_home/runs/BxuRVhUf/_metasmith/task/transforms/bzoYw5jlQsSh]
#  | > 2025-03-20_22-53-19  | [nSyCz0z7myGP] is at [/msm_home/runs/BxuRVhUf/_metasmith/task/data/nSyCz0z7myGP]
#  | > 2025-03-20_22-53-19  | [Ij63CSSFzVxn] is at [/msm_home/runs/BxuRVhUf/_metasmith/task/data/Ij63CSSFzVxn]
#  | > 2025-03-20_22-53-19  | calling nextflow from container
#  | > 2025-03-20_22-53-22  |  N E X T F L O W   ~  version 24.10.5
#  | > 2025-03-20_22-53-22  |
#  | > 2025-03-20_22-53-22  | WARN: It appears you have never run this project before -- Option `-resume` is ignored
#  | > 2025-03-20_22-53-23  | Launching `./workflow.nf` [hungry_thompson] DSL2 - revision: bf92624f1d
#  | > 2025-03-20_22-53-23  |
#  | > 2025-03-20_22-53-24  |
#  | > 2025-03-20_22-53-24  | <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
#  | > 2025-03-20_22-53-24  | log folder at [/msm_home/runs/BxuRVhUf/_metasmith/logs.2025-03-20_22-53-19]
# 2025-03-20_22-53-25  | closing connection
