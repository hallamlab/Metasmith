# %%
import numpy as np

class KeyGenerator:
    def __init__(self, full=False, seed=None) -> None:
        ascii_vocab = [(48, 57), (65, 90), (97, 122)]
        vocab = [chr(i) for g in [range(a, b+1) for a, b in ascii_vocab] for i in g]
        if full: vocab += [c for c in "-_"]
        self.vocab = vocab
        self._generator = np.random.default_rng(seed)

    def GenerateUID(self, l:int=8, blacklist: set[str]=set()) -> str:
        key: str|None = None
        while key is None or key in blacklist:
            digits = self._generator.integers(0, len(self.vocab), l)
            key = "".join([self.vocab[i] for i in digits])
        return key
    
    def FromInt(self, i: int, l: int=8, little_endian=False):
        chunks = [self.vocab[0]]*l
        place = 0
        while i > 0 and place < l:
            chunk_k = i % len(self.vocab)
            i = (i - chunk_k) // len(self.vocab)
            chunks[place] = self.vocab[chunk_k]
            place += 1
        if not little_endian: chunks.reverse()
        return "".join(chunks)
    
    def FromHex(self, hex: str, l: int=8, little_endian=False):
        return self.FromInt(int(hex, 16), l, little_endian)

# %%
from __future__ import annotations
from dataclasses import dataclass, field
import os, sys
from typing import Any, Generator, Iterable, Literal
import hashlib
import numpy as np
import json
from collections import deque
from pathlib import Path

class Namespace:
    def __init__(self) -> None:
        self.node_signatures: dict[int, str] = {}
        self._last_k: int = 0
        self._kg = KeyGenerator(True)
        self._KLEN = 4
        self._MAX_K = len(self._kg.vocab)**self._KLEN

    def NewKey(self):
        self._last_k += 1
        assert self._last_k < self._MAX_K
        return self._last_k, self._kg.FromInt(self._last_k, self._KLEN)

class Hashable:
    def __init__(self, ns: Namespace) -> None:
        self.namespace = ns
        self.hash, self.key = ns.NewKey()

    def __hash__(self) -> int:
        return self.hash
    
    def __eq__(self, __value: object) -> bool:
        K = "key"
        return hasattr(__value, K) and self.key == getattr(__value, K)

class Node(Hashable):
    def __init__(
        self,
        ns: Namespace,
        properties: set[str],
        parents: set[Node],
    ) -> None:
        super().__init__(ns)
        self.namespace = ns
        self.properties = properties
        self.parents = parents
        self._sig: str|None = None
        # self._diffs = set()
        # self._sames = set()

    def __str__(self) -> str:
        return f"({'-'.join(self.properties)}:{self.key})"

    def __repr__(self) -> str:
        return f"{self}"
    
    def IsA(self, other: Node) -> bool:
        # if other.key in self._diffs: return False
        # if other.key in self._sames: return True
        if not other.properties.issubset(self.properties):
            # self._diffs.add(other.key)
            return False
        # self._sames.add(other.key)
        # if compare_lineage: return  other.parents.issubset(self.parents)
        return True

    def Signature(self):
        if self._sig is None:
            psig = ",".join(sorted(p.Signature() for p in self.parents))
            sig = ",".join(sorted(self.properties))
            self._sig = f'{sig}:[{psig}]' if len(self.parents)>0 else sig
        return self._sig

class Dependency(Node):
    def __init__(self, namespace: Namespace, properties: set[str], parents: set[Node]) -> None:
        super().__init__(namespace, properties, parents)

    def __str__(self) -> str:
        return f"(D:{'-'.join(self.properties)})"
    
class Endpoint(Node):
    def __init__(self, namespace: Namespace, properties: set[str], parents: dict[Endpoint, Node]=dict()) -> None:
        super().__init__(namespace, properties, set(parents))
        self._parent_map = parents # real, proto

    def Iterparents(self):
        """real, prototype"""
        for e, p in self._parent_map.items():
            yield e, p

class Transform(Hashable):
    def __init__(self, ns: Namespace) -> None:
        super().__init__(ns)
        self.requires: list[Dependency] = list()
        self.produces: list[Dependency] = list()
        self.deletes: set[Dependency] = set()
        self._ns = ns
        self._input_group_map: dict[int, list[Dependency]] = {}
        self._key = ns.NewKey()
        self._seen: set[str] = set()

    def __str__(self) -> str:
        def _props(d: Dependency):
            return "{"+"-".join(d.properties)+"}"
        return f"{','.join(_props(r) for r in self.requires)}->{','.join(_props(p) for p in self.produces)}"

    def __repr__(self): return f"{self}"

    def AddRequirement(self, properties: Iterable[str], parents: set[Dependency]=set()):
        prototype = Dependency(properties=set(properties), parents=parents, namespace=self._ns)
        return self._add_dependency(self.requires, prototype)

    def AddProduct(self, properties: Iterable[str], parents: set[Dependency]=set()):
        prototype = Dependency(properties=set(properties), parents=parents, namespace=self._ns)
        for d in self.deletes:
            assert not prototype.IsA(d), f"can not produce and delete product[{d}]"
        return self._add_dependency(self.produces, prototype)
    
    # def AddDeletion(self, to_delete: Dependency):
    #     print("warning!, deletion not implemented")
    #     assert to_delete in self.requires, f"{to_delete} not in requirements"
    #     if to_delete in self.deletes: return # already added
    #     for p in self.produces:
    #         assert not p.IsA(to_delete), f"can not produce and delete product [{p}]"
    #     self.deletes.add(to_delete)

    def _add_dependency(self, destination: list[Dependency], prototype: Dependency):
        # _dep = Dependency(properties=set(properties), parents=_parents, namespace=self._ns)
        _dep = prototype
        _parents = _dep.parents
        # assert not any(e.IsA(_dep) for e in destination), f"prev. dep ⊆ new dep"
        # assert not any(_dep.IsA(e) for e in destination), f"new dep ⊆ prev. dep "
        # destination.add(_dep)
        destination.append(_dep)
        if destination == self.requires:
            i = len(self.requires)-1
            for p in _parents:
                assert p in self.requires, f"{p} not added as a requirement"
            self._input_group_map[i] = self._input_group_map.get(i, [])+list(_parents)
        return _dep

    def _sig(self, endpoints: Iterable[Endpoint]):
        # return "".join(e.key for e in endpoints)
        return self.key+"-"+ "".join(e.key for e in endpoints)

    # just all possibilities regardless of lineage
    def Possibilities(self, have: set[Endpoint], constraints: dict[Dependency, Endpoint]=dict()) -> Generator[list[Endpoint], Any, None]:
        matches: list[list[Endpoint]] = []
        constraints_used = False
        for req in self.requires:
            if req in constraints:
                must_use = constraints[req]
                _m = [must_use]
            else:
                _m = [m for m in have if m.IsA(req)]
            if len(_m) == 0: return None
            matches.append(_m)
        if len(constraints)>0 and not constraints_used: return None

        indexes = [0]*len(matches)
        indexes[0] = -1
        def _advance():
            i = 0
            while True:
                indexes[i] += 1
                if indexes[i] < len(matches[i]): return True
                indexes[i] = 0
                i += 1
                if i >= len(matches): return False
        while _advance():
            yield [matches[i][j] for i, j in enumerate(indexes)]
    
    # filter possibilities based on correct lineage
    def Valids(self, matches: Iterable[list[Endpoint]]):
        black_list: set[tuple[int, Endpoint]] = set()
        white_list: set[tuple[int, Endpoint]] = set()

        choosen: list[Endpoint] = []
        for config in matches:
            ok = True
            for i, (e, r) in enumerate(zip(config, self.requires)):
                k = (i, e)
                if k in black_list: ok=False; break
                if k in white_list: continue
                
                parents = self._input_group_map.get(i, [])
                if len(parents) == 0: # no lineage req.
                    white_list.add(k)
                    continue
                
                for prototype in parents:
                    # parent must already be in choosen, since it must have been added
                    # as a req. before being used as a parent during setup
                    found = False
                    for p in choosen:
                        if not p.IsA(prototype): continue
                        if p in e.parents: found=True; break
                    if not found: black_list.add(k); ok=False; break
                if not ok: break
            if ok: yield config

    def Apply(self, inputs: Iterable[tuple[Endpoint, Node]]):
        # deleted = {}
        # for r, (e, e_proto) in zip(self.requires, inputs):
        #     assert e.IsA(r), f"{e_proto}, {e}, {r}"
        #     if r in self.deletes: deleted[e] = e_proto

        inputs_dict = dict(inputs)
        parent_dict: dict[Any, Any] = {}
        for e, _ in inputs_dict.items():
            for p, pproto in e.Iterparents():
                if p in parent_dict: continue
                parent_dict[p] = pproto
        for e, eproto in inputs_dict.items():
            parent_dict[e] = eproto
        produced = {
            Endpoint(
                namespace=self._ns,
                properties=out.properties,
                parents=parent_dict
            ):out
        for out in self.produces}
        # return Application(self, inputs_dict, produced, deleted)
        return Application(self, inputs_dict, produced)

@dataclass
class Application:
    transform: Transform
    used: dict[Endpoint, Node]
    produced: dict[Endpoint, Dependency]
    # deleted: dict[Endpoint, Node]

    def __str__(self) -> str:
        # return f"{self.transform} || {','.join(str(e) for e in self.used.keys())} -> {','.join(str(e) for e in self.produced)} |x {','.join(str(e) for e in self.deleted)}"
        return f"{self.transform} || {','.join(str(e) for e in self.used.keys())}->{','.join(str(e) for e in self.produced)}"

    def __repr__(self) -> str:
        return f"{self}"

@dataclass
class HasSteps:
    steps: int

@dataclass
class Result(HasSteps):
    application: Application
    dependency_plan: list[Application]
    
@dataclass
class DepResult(HasSteps):
    plan: list[Application]
    endpoint: Endpoint

def Solve(given: Iterable[Endpoint], target: Transform, transforms: Iterable[Transform], _debug=False):
    @dataclass
    class State:
        have: dict[Endpoint, Dependency]
        needed: set[Dependency]
        target: Dependency|Transform
        lineage_requirements: dict[Node, Endpoint]
        seen_signatures: set[str]
        depth: int

    def _get_producers_of(target: Dependency):
        for tr in transforms:
            for p in tr.produces:
                if p.IsA(target):
                    yield tr
                    break

    if _debug:
        log_path = Path("./cache/debug_log.txt")
        log_path.parent.mkdir(parents=True, exist_ok=True)
        log = open("./cache/debug_log.txt", "w")
        debug_print = lambda *args: log.write(" ".join(str(a) for a in args)+"\n") if args[0] != "END" else log.close()
    else:
        debug_print = lambda *args: None

    _apply_cache: dict[str, Application] = {}
    def _apply(target: Transform, inputs: Iterable[tuple[Endpoint, Node]]):
        sig  = "".join(e.key+d.key for e, d in inputs)
        if sig in _apply_cache:
            return _apply_cache[sig]
        appl = target.Apply(inputs)
        _apply_cache[sig] = appl
        return appl

    def _satisfies_lineage(tproto: Dependency, candidate: Endpoint):
        for tp_proto in tproto.parents:
            if all(not p.IsA(tp_proto) for p, _ in candidate.Iterparents()):
                return False
        return True

    HORIZON=64
    def _solve_dep(s: State) -> list[DepResult]:
        if s.depth >= HORIZON:
            if _debug: debug_print(f" <-  HORIZON", s.depth)
            return []
        target: Dependency = s.target
        assert isinstance(target, Dependency), f"{s.target}, not dep"
        if _debug: debug_print(f" ->", s.target, s.lineage_requirements)
        if _debug: debug_print(f"   ", s.have.keys())

        candidates:list[DepResult] = []
        for e, eproto in s.have.items():
            if not e.IsA(target): continue
            acceptable = True
            for rproto, r in s.lineage_requirements.items():
                if e == r: continue
                if eproto.IsA(rproto): # e is protype, but explicitly breaks lineage
                    acceptable=False; break

                for p, pproto in e.Iterparents():
                    if rproto.IsA(pproto):
                        if p != r:
                            acceptable=False; break

            if not acceptable:
                continue
            else:
                if _debug: debug_print(f"    ^candidate", e, eproto, e.parents)
                if _debug: debug_print(f"    ^reqs.    ", s.lineage_requirements)
                candidates.append(DepResult(0, [], e))
            # elif quality == 2:
            #     if DEBUG: debug_print(f" <-", s.target, e, "DIRECT")
            #     return [DepResult(0, [], e)]

        def _add_result(res: Result):
            ep: Endpoint|None = None
            for e in res.application.produced:
                if e.IsA(target):
                    ep = e; break
            assert isinstance(ep, Endpoint)
            if not _satisfies_lineage(target, ep): return
            candidates.append(DepResult(
                res.steps,
                res.dependency_plan+[res.application],
                ep,
            ))

        for tr in _get_producers_of(target):
            # if target in tr.deletes: continue
            results = _solve_tr(State(s.have, s.needed, tr, s.lineage_requirements, s.seen_signatures, s.depth))
            for res in results:
                _add_result(res)

        if _debug: debug_print(f" <-", s.target, f"{len(candidates)} sol.", candidates[0].endpoint if len(candidates)>0 else None)
        return candidates

    _transform_cache: dict[str, list[Result]] = {}
    def _solve_tr(s: State) -> list[Result]:
        assert isinstance(s.target, Transform), f"{s.target} not tr"
        target: Transform = s.target
        if _debug: debug_print(f">>>{s.depth:02}", s.target, s.lineage_requirements)
        for h in s.have:
            if _debug: debug_print(f"      ", h)

        # memoization
        sig = "".join(e.key for e in s.have)
        sig += f":{s.target.key}"
        sig += ":"+"".join(e.key for e in s.lineage_requirements.values())
        if sig in _transform_cache:
            if _debug: debug_print(f"<<<{s.depth:02} CACHED: {len(_transform_cache[sig])} solutions")
            return _transform_cache[sig]
        if sig in s.seen_signatures:
            if _debug: debug_print(f"<<<{s.depth:02} FAIL: is loop")
            return []

        plans: list[list[DepResult]] = []
        for i, req in enumerate(s.target.requires):
            req_p = {}
            for proto, e in s.lineage_requirements.items():
                if req.IsA(proto): continue
                req_p[proto] = e

            results = _solve_dep(State(s.have, s.needed|{req}, req, req_p, s.seen_signatures|{sig}, s.depth+1))
            
            if len(results) == 0:
                if _debug: debug_print(f"<<< FAIL", s.target, req)
                return []
            else:
                plans.append(results)

        def _gather_valid_inputs():
            valids: list[list[DepResult]] = []
            ii = 0
            def _gather(req_i: int, req: Dependency, res: DepResult, deps: dict, used: set[Endpoint], inputs: list[DepResult]):
                nonlocal ii; ii += 1         
                if _debug: debug_print(f"          ", deps)
                if _debug: debug_print(f"    ___", req, req.parents)
                if _debug: debug_print(f"        __", res.endpoint, list(res.endpoint.Iterparents()))
                if res.endpoint in used:
                    if _debug: debug_print(f"    ___ FAIL: duplicate input", res.endpoint)
                    return
                # used.add(res.endpoint)

                if not _satisfies_lineage(req, res.endpoint):
                    if _debug: debug_print(f"    ___ FAIL: unsatisfied lineage", req)
                    return

                for rproto in req.parents:
                    r = deps[rproto]
                    # if all(not p.IsA(rproto) for p, pproto in res.endpoint.Iterparents()):
                    #     if DEBUG: debug_print(f"    ___ FAIL: unsatisfied lineage", rproto)
                    #     _fail=True; break
                    res_parents = list(res.endpoint.Iterparents())
                    res_parents.reverse()
                    for p, pproto in res_parents:
                        if not p.IsA(rproto): continue
                        if p!=r:
                            if _debug: debug_print(f"    ___ FAIL: lineage mismatch", p, r)
                            return
                        else:
                            break # in the case of asm -> bin, the closest ancestor takes priority
                # deps[req] = res.endpoint

                if req_i >= len(target.requires)-1:
                    valids.append(inputs+[res])
                else:
                    req_i += 1
                    for i, next_res in enumerate(plans[req_i]):
                        _gather(req_i, target.requires[req_i], next_res, deps|{req:res.endpoint}, used|{res.endpoint}, inputs+[res])
            req_i = 0
            for i, next_res in enumerate(plans[req_i]):
                _gather(0, target.requires[req_i], next_res, {}, set(), [])
            total = 1
            for s in plans:
                total *= len(s)
            if _debug: debug_print(f"    ## {ii} visited, {total} combos")
            return valids

        if _debug: debug_print(f"<<<{s.depth:02}", s.target, s.lineage_requirements)
        if _debug: debug_print(f"     ", [len(x) for x in plans])
        solutions: list[Result] = []
        # for inputs in _iter_satisfies():
        for inputs in _gather_valid_inputs():
            my_appl = _apply(s.target, [(res.endpoint, req) for req, res in zip(s.target.requires, inputs)])
            consolidated_plan: list[Application] = []
            produced_sigs: set[str] = {p.Signature() for p in my_appl.produced}
            # if DEBUG: debug_print(f"   __", my_appl)
            for res in inputs:
                for appl in res.plan:
                    if all(p.Signature() in produced_sigs for p in appl.produced): continue
                    consolidated_plan.append(appl)
                    produced_sigs = produced_sigs.union(p.Signature() for p in appl.produced)
            solutions.append(Result(
                len(consolidated_plan),
                my_appl,
                consolidated_plan,
            ))
            # if DEBUG: debug_print(f"    *", my_appl)
            # if DEBUG: debug_print(f"     ", [res.endpoint for res in inputs])
            # if DEBUG: debug_print(f"    .", target.requires)
            # for appl in consolidated_plan:
            #     if DEBUG: debug_print(f"    __", appl)
        if _debug: debug_print(f"     ", f"{len(solutions)} sol.", solutions[0].application.produced if len(solutions)>0 else None)
        solutions = sorted(solutions, key=lambda s: s.steps)
        _transform_cache[sig] = solutions
        return solutions

    input_tr = Transform(target._ns)
    given_dict = {g:input_tr.AddProduct(g.properties) for g in given}
    res = _solve_tr(State(given_dict, set(), target, {}, set(), 0))
    if _debug: debug_print("END")
    return res


def _set(s: str):
    return set(s.split(", "))
 
transforms = []
NS = Namespace()

# t = Transform(NS)
# t.AddRequirement(_set("dna"))
# t.AddProduct(_set("contigs, asm, annable"))
# transforms.append(t)

# t = Transform(NS)
# r = t.AddRequirement(_set("dna"))
# t.AddRequirement(_set("contigs, asm"), {r})
# t.AddProduct(_set("contigs, bin, annable"))
# transforms.append(t)

# t = Transform(NS)
# t.AddRequirement(_set("db"))
# t.AddRequirement(_set("annable"))
# t.AddProduct(_set("ann"))
# transforms.append(t)

# t = Transform(NS)
# ann = t.AddRequirement(_set("annable"))
# r = t.AddRequirement(_set("db, cog"))
# t.AddRequirement(_set("ann"), {r, ann})
# r = t.AddRequirement(_set("db, kegg"))
# t.AddRequirement(_set("ann"), {r, ann})
# t.AddProduct(_set("table"))
# transforms.append(t)

# t = Transform(NS)
# db1 = t.AddRequirement(_set("db, cog"))
# db2 = t.AddRequirement(_set("db, kegg"))
# asm = t.AddRequirement(_set("contigs, asm"))
# bin = t.AddRequirement(_set("contigs, bin"))
# # t.AddRequirement(_set("ann"), {asm, db1})
# # t.AddRequirement(_set("ann"), {asm, db2})
# # t.AddRequirement(_set("ann"), {bin, db1})
# # t.AddRequirement(_set("ann"), {bin, db2})
# t.AddRequirement(_set("table"), {asm, db1, db2})
# t.AddRequirement(_set("table"), {bin, db1, db2})
# t.AddProduct(_set("figure"))
# transforms.append(t)

# t = Transform(NS)
# t.AddRequirement(_set("precog"))
# t.AddProduct(_set("db, cog"))
# transforms.append(t)

# t = Transform(NS)
# t.AddRequirement(_set("prekegg"))
# t.AddProduct(_set("db, kegg"))
# transforms.append(t)

t = Transform(NS)
d = t.AddRequirement(_set("a"))
t.AddProduct(_set("b"))
# t.AddDeletion(d)
transforms.append(t)

t = Transform(NS)
d = t.AddRequirement(_set("b"))
t.AddProduct(_set("c"))
# t.AddDeletion(d)
transforms.append(t)

t = Transform(NS)
d = t.AddRequirement(_set("b"))
t.AddProduct(_set("x"))
transforms.append(t)

haves = [Endpoint(NS, _set(r)) for r in [
    # "precog",
    # # "db, cog",
    # "db, kegg",
    "a",
]]

target = Transform(NS)
r = target.AddRequirement(_set("c"))
r = target.AddRequirement(_set("x"))
# db = target.AddRequirement(_set("cog"))
# target.AddRequirement(_set("ann"), {db, r})
# target.AddRequirement(_set("ann"), {db})

# r = target.AddRequirement(_set("bin"))
# target.AddRequirement(_set("table"), {r})

# target.AddRequirement(_set("figure"))

def _print_sol(plan: Result):
    for i, step in enumerate(plan.dependency_plan):
        print(f"step {i+1}")
        print(step.transform)
        print("used")
        for x in step.used:
            print(" ", x)
        print("produced")
        for x in step.produced:
            print(" ", x)
        # if len(step.deleted) > 0:
        #     print("deleted")
        #     for x in step.deleted:
        #         print(" ", x)
        print()

solutions = None
def _test():
    global solutions
    solutions = Solve(haves, target, transforms, _debug=True)
    print(f"{len(solutions)} solutions")
    for res in solutions:
        _print_sol(res)
        # print(res.steps)
        # return f"{len(solutions)} solutions", res.dependency_plan+[res.application]
    print("//")
    # if res is not None:
_test()
# Out:
# 1 solutions
# step 1
# {a}->{b}
# used
#   (a:000D)
# produced
#   (b:000L)
#
# step 2
# {b}->{c}
# used
#   (b:000L)
# produced
#   (c:000M)
#
# step 3
# {b}->{x}
# used
#   (b:000L)
# produced
#   (x:000N)
#
# //

# %%
for res in solutions:
    for a in res.dependency_plan:
        print(a)
    print(res.application)
    print()
# Out:
# {a}->{b} || (a:000D)->(b:000L)
# {b}->{c} || (b:000L)->(c:000M)
# {b}->{x} || (b:000L)->(x:000N)
# {c},{x}-> || (c:000M),(x:000N)->

# %%
transforms
# Out:
# [{a}->{b}, {b}->{c}, {b}->{x}]

# %%
transforms = []
NS = Namespace()

t = Transform(NS)
t.AddRequirement({"dna", "raw reads"})
t.AddProduct({"assembly", "contigs"})
transforms.append(t)

t = Transform(NS)
reads = t.AddRequirement({"dna", "raw reads"})
t.AddRequirement({"contigs", "assembly"}, parents={reads})
t.AddProduct({"binned", "contigs"})
transforms.append(t)


have = [
    Endpoint(NS, {"dna", "raw reads", "sra", "metagenomic"}),
]

target = Transform(NS)
target.AddRequirement({"binned", "contigs"})

plan = Solve(have, target, transforms)[0] # first solution

# %%
_print_sol(plan)
# Out:
# step 1
# {raw reads-dna}->{assembly-contigs}
# used
#   (raw reads-sra-metagenomic-dna:000A)
# produced
#   (assembly-contigs:000H)
#
# step 2
# {raw reads-dna},{assembly-contigs}->{binned-contigs}
# used
#   (raw reads-sra-metagenomic-dna:000A)
#   (assembly-contigs:000H)
# produced
#   (binned-contigs:000I)

# %%
transforms = []
NS = Namespace()

t = Transform(NS)
t.AddRequirement({"genomic", "contigs"})
t.AddProduct({"orfs"})
transforms.append(t)

t = Transform(NS)
t.AddRequirement({"protein reference"})
t.AddRequirement({"orfs"})
t.AddProduct({"annotations"})
transforms.append(t)

have = [
    Endpoint(NS, {"genomic", "contigs"}),
    Endpoint(NS, {"protein reference", "KEGG"}),
    Endpoint(NS, {"protein reference", "COG"}),
    Endpoint(NS, {"protein reference", "metacyc"}),
]

target = Transform(NS)
kegg = target.AddRequirement({"protein reference", "KEGG"})
metacyc = target.AddRequirement({"protein reference", "metacyc"})
target.AddRequirement({"annotations"}, {kegg})
target.AddRequirement({"annotations"}, {metacyc})

plan = Solve(have, target, transforms)[0]
_print_sol(plan)
# Out:
# step 1
# {genomic-contigs}->{orfs}
# used
#   (genomic-contigs:000A)
# produced
#   (orfs:000Q)
#
# step 2
# {protein reference},{orfs}->{annotations}
# used
#   (protein reference-KEGG:000B)
#   (orfs:000Q)
# produced
#   (annotations:000R)
#
# step 3
# {protein reference},{orfs}->{annotations}
# used
#   (protein reference-metacyc:000D)
#   (orfs:000Q)
# produced
#   (annotations:000T)

# %%
transforms = []
NS = Namespace()

t = Transform(NS)
t.AddRequirement(_set("dna"))
t.AddProduct(_set("contigs, assembly, genomic"))
transforms.append(t)

t = Transform(NS)
r = t.AddRequirement(_set("dna"))
t.AddRequirement(_set("contigs, assembly"), {r})
t.AddProduct(_set("contigs, bin, genomic"))
transforms.append(t)

t = Transform(NS)
t.AddRequirement(_set("reference"))
t.AddRequirement(_set("genomic"))
t.AddProduct(_set("annotation"))
transforms.append(t)

t = Transform(NS)
genome = t.AddRequirement(_set("genomic"))
ref_cog = t.AddRequirement(_set("reference, COG"))
t.AddRequirement(_set("annotation"), {ref_cog, genome})
ref_kegg = t.AddRequirement(_set("reference, KEGG"))
t.AddRequirement(_set("annotation"), {ref_kegg, genome})
t.AddProduct(_set("table"))
transforms.append(t)

t = Transform(NS)
ref_cog = t.AddRequirement(_set("reference, COG"))
ref_kegg = t.AddRequirement(_set("reference, KEGG"))
asm_genome = t.AddRequirement(_set("contigs, assembly"))
bin_genome = t.AddRequirement(_set("contigs, bin"))
t.AddRequirement(_set("table"), {asm_genome, ref_cog, ref_kegg})
t.AddRequirement(_set("table"), {bin_genome, ref_cog, ref_kegg})
t.AddProduct(_set("summary figure"))
transforms.append(t)

have = [
    Endpoint(NS, {"dna", "raw reads"}),
    Endpoint(NS, {"reference", "COG"}),
    Endpoint(NS, {"reference", "KEGG"}),
]

target = Transform(NS)
target.AddRequirement({"summary figure"})

plan = Solve(have, target, transforms)[0]
_print_sol(plan)
# Out:
# step 1
# {dna}->{assembly-genomic-contigs}
# used
#   (raw reads-dna:000W)
# produced
#   (assembly-genomic-contigs:000h)
#
# step 2
# {dna},{assembly-contigs}->{bin-genomic-contigs}
# used
#   (raw reads-dna:000W)
#   (assembly-genomic-contigs:000h)
# produced
#   (bin-genomic-contigs:000i)
#
# step 3
# {reference},{genomic}->{annotation}
# used
#   (COG-reference:000X)
#   (assembly-genomic-contigs:000h)
# produced
#   (annotation:000j)
#
# step 4
# {reference},{genomic}->{annotation}
# used
#   (KEGG-reference:000Y)
#   (assembly-genomic-contigs:000h)
# produced
#   (annotation:000l)
#
# step 5
# {genomic},{COG-reference},{annotation},{KEGG-reference},{annotation}->{table}
# used
#   (assembly-genomic-contigs:000h)
#   (COG-reference:000X)
#   (annotation:000j)
#   (KEGG-reference:000Y)
#   (annotation:000l)
# produced
#   (table:000n)
#
# step 6
# {reference},{genomic}->{annotation}
# used
#   (COG-reference:000X)
#   (bin-genomic-contigs:000i)
# produced
#   (annotation:000k)
#
# step 7
# {reference},{genomic}->{annotation}
# used
#   (KEGG-reference:000Y)
#   (bin-genomic-contigs:000i)
# produced
#   (annotation:000m)
#
# step 8
# {genomic},{COG-reference},{annotation},{KEGG-reference},{annotation}->{table}
# used
#   (bin-genomic-contigs:000i)
#   (COG-reference:000X)
#   (annotation:000k)
#   (KEGG-reference:000Y)
#   (annotation:000m)
# produced
#   (table:000o)
#
# step 9
# {COG-reference},{KEGG-reference},{assembly-contigs},{bin-contigs},{table},{table}->{summary figure}
# used
#   (COG-reference:000X)
#   (KEGG-reference:000Y)
#   (assembly-genomic-contigs:000h)
#   (bin-genomic-contigs:000i)
#   (table:000n)
#   (table:000o)
# produced
#   (summary figure:000p)

# %%
transforms = []
NS = Namespace()

t = Transform(NS) # assembly
t.AddRequirement({"dna", "raw reads"})
t.AddProduct({"assembly", "contigs"})
transforms.append(t)

t = Transform(NS) # fosmid assembly
t.AddRequirement({"dna", "raw reads", "fosmid"})
t.AddRequirement({"dna", "end seq."})
t.AddProduct({"fosmids", "assembly", "contigs"})
transforms.append(t)

t = Transform(NS) # binning
reads = t.AddRequirement({"dna", "raw reads"})
t.AddRequirement({"contigs", "assembly"}, parents={reads})
t.AddProduct({"binned", "contigs"})
transforms.append(t)

t = Transform(NS) # genomeQC
t.AddRequirement({"binned", "contigs"})
t.AddProduct({"binned", "contigs", "med quality"})
t.AddProduct({"taxonomy", "GTDB-TK"})
t.AddProduct({"table", "checkM stats"})
transforms.append(t)

t = Transform(NS) # annotation
t.AddRequirement({"assembly", "contigs"})
t.AddProduct({"orfs"})
t.AddProduct({"annotations", "metapathways"})
transforms.append(t)

t = Transform(NS) # taxonomy
t.AddRequirement({"contigs"})
t.AddProduct({"taxonomy", "GTDB-TK"})
transforms.append(t)

have = [
    Endpoint(NS, {"dna", "raw reads", "metagenomic"}),
]

target = Transform(NS)
target.AddRequirement({"annotations", "metapathways"})
target.AddRequirement({"taxonomy", "GTDB-TK"})

plan = Solve(have, target, transforms)[0]
_print_sol(plan)
# Out:
# step 1
# {raw reads-dna}->{assembly-contigs}
# used
#   (raw reads-metagenomic-dna:000U)
# produced
#   (assembly-contigs:000c)
#
# step 2
# {assembly-contigs}->{orfs},{annotations-metapathways}
# used
#   (assembly-contigs:000c)
# produced
#   (orfs:000d)
#   (annotations-metapathways:000e)
#
# step 3
# {contigs}->{taxonomy-GTDB-TK}
# used
#   (assembly-contigs:000c)
# produced
#   (taxonomy-GTDB-TK:000j)

# %%
NS = Namespace()
transforms = []

t = Transform(NS) # assembly <-> bins
t.AddRequirement({"assembly"})
t.AddProduct({"bins"})
transforms.append(t)
t = Transform(NS)
t.AddRequirement({"bins"})
t.AddProduct({"assembly"})
transforms.append(t)

t = Transform(NS) # bins <-> tax
t.AddRequirement({"bins"})
t.AddProduct({"tax"})
transforms.append(t)
t = Transform(NS)
t.AddRequirement({"tax"})
t.AddProduct({"bins"})
transforms.append(t)

t = Transform(NS) # bins <-> contigs
t.AddRequirement({"bins"})
t.AddProduct({"contigs"})
transforms.append(t)
t = Transform(NS)
t.AddRequirement({"contigs"})
t.AddProduct({"bins"})
transforms.append(t)

t = Transform(NS) # contigs <-> ORFs
t.AddRequirement({"contigs"})
t.AddProduct({"ORFs"})
transforms.append(t)
t = Transform(NS)
t.AddRequirement({"ORFs"})
t.AddProduct({"contigs"})
transforms.append(t)

t = Transform(NS) # ORFs <-> annotation
t.AddRequirement({"ORFs"})
t.AddProduct({"annotation"})
transforms.append(t)
t = Transform(NS) 
t.AddRequirement({"annotation"})
t.AddProduct({"ORFs"})
transforms.append(t)


have = [
    Endpoint(NS, {"annotation"}),
]

target = Transform(NS)
tax = target.AddRequirement({"tax"})
target.AddRequirement({"annotation"}, {tax})

plan = Solve(have, target, transforms)[0]
_print_sol(plan)
# Out:
# step 1
# {annotation}->{ORFs}
# used
#   (annotation:000f)
# produced
#   (ORFs:000n)
#
# step 2
# {ORFs}->{contigs}
# used
#   (ORFs:000n)
# produced
#   (contigs:000o)
#
# step 3
# {contigs}->{bins}
# used
#   (contigs:000o)
# produced
#   (bins:000p)
#
# step 4
# {bins}->{tax}
# used
#   (bins:000p)
# produced
#   (tax:000t)
#
# step 5
# {tax}->{bins}
# used
#   (tax:000t)
# produced
#   (bins:000u)
#
# step 6
# {bins}->{contigs}
# used
#   (bins:000u)
# produced
#   (contigs:000x)
#
# step 7
# {contigs}->{ORFs}
# used
#   (contigs:000x)
# produced
#   (ORFs:0010)
#
# step 8
# {ORFs}->{annotation}
# used
#   (ORFs:0010)
# produced
#   (annotation:0016)

# %%
NS = Namespace()
transforms = []

for _destination, adjacents in [
    ("town",    ["field"]),
    ("field",   ["town", "castle"]),
    ("castle",  ["field"]),
]:
    for _source in adjacents:
        t = Transform(NS)
        t.AddRequirement(_set(_source))
        t.AddProduct(_set(_destination))
        transforms.append(t)

start = [
    Endpoint(NS, {"town"}),
]

target = Transform(NS)
target.AddRequirement({"castle"})

plan = Solve(start, target, transforms)[0]
_print_sol(plan)
# Out:
# step 1
# {town}->{field}
# used
#   (town:000H)
# produced
#   (field:000O)
#
# step 2
# {field}->{castle}
# used
#   (field:000O)
# produced
#   (castle:000P)

# %%
transforms
# Out:
# [{field}->{town}, {town}->{field}, {castle}->{field}, {field}->{castle}]

# %%
NS = Namespace()
transforms = []

t = Transform(NS)
t.AddRequirement(_set("reads"))
t.AddProduct(_set("annable, taxable"))
transforms.append(t)

t = Transform(NS)
t.AddRequirement(_set("annable"))
t.AddProduct(_set("ann"))
transforms.append(t)

# t = Transform(NS)
# t.AddRequirement(_set("ann"))
# t.AddProduct(_set("annable"))
# transforms.append(t)

t = Transform(NS)
t.AddRequirement(_set("taxable"))
t.AddProduct(_set("tax"))
transforms.append(t)

t = Transform(NS)
d_parent = t.AddRequirement(_set("annable, taxable"))
d_ann = t.AddRequirement(_set("ann"), {d_parent})
d_tax = t.AddRequirement(_set("tax"), {d_parent})
t.AddProduct(_set("sum"))
transforms.append(t)

# M, N = 2, 1
# M, N = 2, 2
# M, N = 50, 2
# M, N = 64, 64
M, N = 128, 128
haves = [Endpoint(NS, _set(f"{i+1}, reads")) for i in range(M)]

target = Transform(NS)
# for e in haves[-N:]:
for e in haves[:N]:
    de = target.AddRequirement(e.properties)
    target.AddRequirement(_set("sum"), {de})
    # target.AddRequirement(_set("sum"))

print("Start")
# %prun r = Solve(haves, target, transforms)
# %prun solutions = Solve(haves, target, transforms)
# f"input size [{N}], states checked [{r.steps}], {r.message}, {len(target.requires)}"
# Out:
# Start
#          1472741 function calls (1438028 primitive calls) in 0.487 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 33536/513    0.110    0.000    0.311    0.001 3874813944.py:387(_gather)
#    180864    0.058    0.000    0.134    0.000 3874813944.py:290(<genexpr>)
#    282240    0.050    0.000    0.062    0.000 3874813944.py:86(Iterparents)
#     50560    0.049    0.000    0.210    0.000 3874813944.py:288(_satisfies_lineage)
#    216216    0.043    0.000    0.069    0.000 3874813944.py:57(IsA)
#    216216    0.026    0.000    0.026    0.000 {method 'issubset' of 'set' objects}
#         1    0.023    0.023    0.029    0.029 history.py:55(only_when_enabled)
#     50944    0.021    0.000    0.151    0.000 {built-in method builtins.all}
#    137860    0.014    0.000    0.014    0.000 3874813944.py:29(__hash__)
#     32896    0.012    0.000    0.020    0.000 3874813944.py:32(__eq__)
#     85272    0.012    0.000    0.012    0.000 {method 'items' of 'dict' objects}
#     17024    0.011    0.000    0.091    0.000 3874813944.py:328(_add_result)
#   262/256    0.009    0.000    0.450    0.002 3874813944.py:295(_solve_dep)
#     134/1    0.005    0.000    0.459    0.459 3874813944.py:351(_solve_tr)
#     33538    0.005    0.000    0.005    0.000 {method 'reverse' of 'list' objects}
#     32917    0.004    0.000    0.004    0.000 {built-in method builtins.hasattr}
#         1    0.004    0.004    0.032    0.032 decorator.py:229(fun)
#     32942    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#       513    0.003    0.000    0.007    0.000 3874813944.py:202(Apply)
#      2720    0.003    0.000    0.004    0.000 {method 'join' of 'str' objects}
# 17683/17675    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
# 4224/3072    0.001    0.000    0.004    0.000 3874813944.py:67(Signature)
#     17286    0.001    0.000    0.001    0.000 3874813944.py:359(<genexpr>)
#       2/1    0.001    0.001    0.459    0.459 <string>:1(<module>)
#      1152    0.001    0.000    0.002    0.000 {method 'union' of 'set' objects}
#       642    0.001    0.000    0.002    0.000 342373234.py:18(FromInt)
#         3    0.001    0.000    0.003    0.001 socket.py:698(send_multipart)
# 1285/1029    0.001    0.000    0.002    0.000 {built-in method builtins.sorted}
# 1792/1664    0.001    0.000    0.002    0.000 3874813944.py:69(<genexpr>)
#        22    0.001    0.000    0.001    0.000 socket.py:621(send)
#      5325    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#      3626    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       513    0.001    0.000    0.008    0.000 3874813944.py:280(_apply)
#      2816    0.001    0.000    0.001    0.000 3874813944.py:443(<genexpr>)
#        12    0.001    0.000    0.173    0.014 base_events.py:1908(_run_once)
#      2304    0.001    0.000    0.001    0.000 3874813944.py:445(<genexpr>)
#       512    0.000    0.000    0.003    0.000 3874813944.py:82(__init__)
#       640    0.000    0.000    0.003    0.000 3874813944.py:37(__init__)
#         5    0.000    0.000    0.175    0.035 3874813944.py:384(_gather_valid_inputs)
#       642    0.000    0.000    0.002    0.000 3874813944.py:19(NewKey)
#       128    0.000    0.000    0.001    0.000 3874813944.py:113(AddProduct)
#        12    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#       5/1    0.000    0.000    0.459    0.459 {built-in method builtins.exec}
#       395    0.000    0.000    0.001    0.000 3874813944.py:264(_get_producers_of)
#       641    0.000    0.000    0.002    0.000 3874813944.py:25(__init__)
#        12    0.000    0.000    0.004    0.000 selectors.py:451(select)
#        20    0.000    0.000    0.000    0.000 ipkernel.py:770(_clean_thread_parent_frames)
#      1537    0.000    0.000    0.000    0.000 3874813944.py:281(<genexpr>)
#       128    0.000    0.000    0.001    0.000 3874813944.py:75(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         6    0.000    0.000    0.000    0.000 dataclasses.py:760(_get_field)
#         8    0.000    0.000    0.000    0.000 attrsettr.py:65(_get_attr_opt)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        10    0.000    0.000    0.000    0.000 threading.py:1533(enumerate)
#         9    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:921(_process_class)
#       396    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         9    0.000    0.000    0.000    0.000 iostream.py:616(_flush)
#         4    0.000    0.000    0.000    0.000 socket.py:777(recv_multipart)
#        13    0.000    0.000    0.029    0.002 events.py:86(_run)
#        22    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         8    0.000    0.000    0.000    0.000 attrsettr.py:42(__getattr__)
#         4    0.000    0.000    0.028    0.007 iostream.py:157(_handle_event)
#        13    0.000    0.000    0.029    0.002 {method 'run' of '_contextvars.Context' objects}
#        11    0.000    0.000    0.001    0.000 ioloop.py:742(_run_callback)
#        53    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         9    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#        70    0.000    0.000    0.000    0.000 threading.py:1196(ident)
#        25    0.000    0.000    0.000    0.000 base_events.py:732(time)
#       128    0.000    0.000    0.000    0.000 3874813944.py:127(_add_dependency)
#       156    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.007    0.002 iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 history.py:845(writeout_cache)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#        10    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#       2/1    0.000    0.000    0.000    0.000 inspect.py:2463(_signature_from_callable)
#        53    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        26    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        18    0.000    0.000    0.000    0.000 dataclasses.py:701(_is_type)
#        21    0.000    0.000    0.000    0.000 events.py:127(__lt__)
#       513    0.000    0.000    0.000    0.000 3874813944.py:457(<lambda>)
#        12    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:568(_init_fn)
#         4    0.000    0.000    0.000    0.000 encoder.py:205(iterencode)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#        21    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#        12    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         4    0.000    0.000    0.029    0.007 zmqstream.py:607(_handle_events)
#         2    0.000    0.000    0.000    0.000 base_events.py:783(call_soon)
#         1    0.000    0.000    0.000    0.000 inspect.py:2368(_signature_from_function)
#       134    0.000    0.000    0.000    0.000 3874813944.py:361(<genexpr>)
#        11    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#        25    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#        21    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         4    0.000    0.000    0.028    0.007 zmqstream.py:580(_run_callback)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         3    0.000    0.000    0.016    0.005 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 inspect.py:175(get_annotations)
#         1    0.000    0.000    0.000    0.000 session.py:754(send)
#         3    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:687(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         4    0.000    0.000    0.028    0.007 zmqstream.py:648(_handle_recv)
#         3    0.000    0.000    0.000    0.000 dataclasses.py:449(_create_fn)
#         3    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         3    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#        57    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 inspect.py:2729(__init__)
#        13    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#        18    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:3015(__init__)
#         8    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         4    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:710(_update_handler)
#        19    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3279(__str__)
#         3    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#        43    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 __init__.py:183(dumps)
#         1    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#         3    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:765(call_at)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#        15    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 session.py:690(serialize)
#         6    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         4    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.459    0.459 3874813944.py:254(Solve)
#         8    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:1255(wrap)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         4    0.000    0.000    0.000    0.000 encoder.py:183(encode)
#        17    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#         4    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         3    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 base_events.py:1893(_add_callback)
#         6    0.000    0.000    0.000    0.000 inspect.py:2816(__str__)
#         2    0.000    0.000    0.028    0.014 asyncio.py:200(_handle_events)
#         4    0.000    0.000    0.000    0.000 session.py:92(json_packer)
#         1    0.000    0.000    0.000    0.000 inspect.py:3067(from_callable)
#         1    0.000    0.000    0.000    0.000 session.py:649(msg)
#         7    0.000    0.000    0.000    0.000 inspect.py:1460(formatannotation)
#         1    0.000    0.000    0.000    0.000 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         6    0.000    0.000    0.000    0.000 dataclasses.py:404(field)
#         1    0.000    0.000    0.000    0.000 hmac.py:122(copy)
#         1    0.000    0.000    0.000    0.000 base_events.py:741(call_later)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:107(json_default)
#         1    0.000    0.000    0.000    0.000 inspect.py:2097(_signature_bound_method)
#         1    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#        36    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:747(unwrap)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:428(_fields_in_init_order)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 events.py:111(__init__)
#        59    0.000    0.000    0.000    0.000 typing.py:2132(cast)
#         1    0.000    0.000    0.000    0.000 session.py:675(sign)
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:250(_recursive_repr)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:864(_set_new_attribute)
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:627(_repr_fn)
#         1    0.000    0.000    0.000    0.000 session.py:645(msg_header)
#        12    0.000    0.000    0.000    0.000 dataclasses.py:683(_is_classvar)
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         1    0.000    0.000    0.000    0.000 3874813944.py:92(__init__)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2635(validate)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:857(_set_qualname)
#         8    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:812(_call_soon)
#         8    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#         4    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:489(_field_init)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:566(sending)
#         1    0.000    0.000    0.000    0.000 session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 session.py:281(extract_header)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         4    0.000    0.000    0.000    0.000 hmac.py:117(update)
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2123(_signature_is_builtin)
#         3    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         2    0.000    0.000    0.000    0.000 dataclasses.py:437(_tuple_str)
#         8    0.000    0.000    0.000    0.000 inspect.py:3062(<genexpr>)
#         1    0.000    0.000    0.000    0.000 session.py:272(msg_header)
#        30    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#        12    0.000    0.000    0.000    0.000 dataclasses.py:691(_is_initvar)
#         2    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         8    0.000    0.000    0.000    0.000 zmqstream.py:562(receiving)
#        13    0.000    0.000    0.000    0.000 dataclasses.py:461(<genexpr>)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.001    0.001 dataclasses.py:1238(dataclass)
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 3874813944.py:255(State)
#         1    0.000    0.000    0.000    0.000 inspect.py:3325(signature)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 hmac.py:161(hexdigest)
#         4    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         7    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:271(send_multipart)
#         3    0.000    0.000    0.000    0.000 inspect.py:2005(_signature_get_user_defined_method)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:309(__init__)
#        12    0.000    0.000    0.000    0.000 dataclasses.py:697(_is_kw_only)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 jsonutil.py:38(_ensure_tzinfo)
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#        17    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 inspect.py:3083(replace)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         6    0.000    0.000    0.000    0.000 dataclasses.py:549(_init_param)
#         1    0.000    0.000    0.000    0.000 inspect.py:2135(_signature_is_functionlike)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         7    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 dataclasses.py:477(_field_assign)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:661(_cmp_fn)
#         4    0.000    0.000    0.000    0.000 encoder.py:105(__init__)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         3    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:432(<genexpr>)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:1142(<genexpr>)
#         3    0.000    0.000    0.000    0.000 inspect.py:371(isfunction)
#         3    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 iostream.py:725(_hooks)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:718(<lambda>)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x556668941300}
#         2    0.000    0.000    0.000    0.000 inspect.py:295(isclass)
#         2    0.000    0.000    0.000    0.000 inspect.py:767(_is_wrapper)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:146(update_abstractmethods)
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 traitlets.py:2558(_validate_bounds)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         3    0.000    0.000    0.000    0.000 base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 inspect.py:2786(default)
#         1    0.000    0.000    0.000    0.000 inspect.py:517(isbuiltin)
#         1    0.000    0.000    0.000    0.000 inspect.py:303(ismethoddescriptor)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:433(<genexpr>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 hmac.py:139(_current)
#         2    0.000    0.000    0.000    0.000 inspect.py:3079(return_annotation)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:879(_hash_set_none)

# %%
print(len(solutions))
for i, res in enumerate(solutions):
    print(res.steps)
    for a in res.dependency_plan:
        print(a)
    print(res.application)
    print()
    if i > 10: break
# Out:
# 1
# 512
# {reads}->{annable-taxable} || (reads-1:000J)->(annable-taxable:008N)
# {annable}->{ann} || (annable-taxable:008N)->(ann:00AN)
# {taxable}->{tax} || (annable-taxable:008N)->(tax:00CN)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008N),(ann:00AN),(tax:00CN)->(sum:00EN)
# {reads}->{annable-taxable} || (2-reads:000K)->(annable-taxable:008O)
# {annable}->{ann} || (annable-taxable:008O)->(ann:00AO)
# {taxable}->{tax} || (annable-taxable:008O)->(tax:00CO)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008O),(ann:00AO),(tax:00CO)->(sum:00EO)
# {reads}->{annable-taxable} || (3-reads:000L)->(annable-taxable:008P)
# {annable}->{ann} || (annable-taxable:008P)->(ann:00AP)
# {taxable}->{tax} || (annable-taxable:008P)->(tax:00CP)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008P),(ann:00AP),(tax:00CP)->(sum:00EP)
# {reads}->{annable-taxable} || (4-reads:000M)->(annable-taxable:008Q)
# {annable}->{ann} || (annable-taxable:008Q)->(ann:00AQ)
# {taxable}->{tax} || (annable-taxable:008Q)->(tax:00CQ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008Q),(ann:00AQ),(tax:00CQ)->(sum:00EQ)
# {reads}->{annable-taxable} || (reads-5:000N)->(annable-taxable:008R)
# {annable}->{ann} || (annable-taxable:008R)->(ann:00AR)
# {taxable}->{tax} || (annable-taxable:008R)->(tax:00CR)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008R),(ann:00AR),(tax:00CR)->(sum:00ER)
# {reads}->{annable-taxable} || (6-reads:000O)->(annable-taxable:008S)
# {annable}->{ann} || (annable-taxable:008S)->(ann:00AS)
# {taxable}->{tax} || (annable-taxable:008S)->(tax:00CS)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008S),(ann:00AS),(tax:00CS)->(sum:00ES)
# {reads}->{annable-taxable} || (reads-7:000P)->(annable-taxable:008T)
# {annable}->{ann} || (annable-taxable:008T)->(ann:00AT)
# {taxable}->{tax} || (annable-taxable:008T)->(tax:00CT)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008T),(ann:00AT),(tax:00CT)->(sum:00ET)
# {reads}->{annable-taxable} || (8-reads:000Q)->(annable-taxable:008U)
# {annable}->{ann} || (annable-taxable:008U)->(ann:00AU)
# {taxable}->{tax} || (annable-taxable:008U)->(tax:00CU)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008U),(ann:00AU),(tax:00CU)->(sum:00EU)
# {reads}->{annable-taxable} || (reads-9:000R)->(annable-taxable:008V)
# {annable}->{ann} || (annable-taxable:008V)->(ann:00AV)
# {taxable}->{tax} || (annable-taxable:008V)->(tax:00CV)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008V),(ann:00AV),(tax:00CV)->(sum:00EV)
# {reads}->{annable-taxable} || (10-reads:000S)->(annable-taxable:008W)
# {annable}->{ann} || (annable-taxable:008W)->(ann:00AW)
# {taxable}->{tax} || (annable-taxable:008W)->(tax:00CW)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008W),(ann:00AW),(tax:00CW)->(sum:00EW)
# {reads}->{annable-taxable} || (11-reads:000T)->(annable-taxable:008X)
# {annable}->{ann} || (annable-taxable:008X)->(ann:00AX)
# {taxable}->{tax} || (annable-taxable:008X)->(tax:00CX)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008X),(ann:00AX),(tax:00CX)->(sum:00EX)
# {reads}->{annable-taxable} || (12-reads:000U)->(annable-taxable:008Y)
# {annable}->{ann} || (annable-taxable:008Y)->(ann:00AY)
# {taxable}->{tax} || (annable-taxable:008Y)->(tax:00CY)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008Y),(ann:00AY),(tax:00CY)->(sum:00EY)
# {reads}->{annable-taxable} || (13-reads:000V)->(annable-taxable:008Z)
# {annable}->{ann} || (annable-taxable:008Z)->(ann:00AZ)
# {taxable}->{tax} || (annable-taxable:008Z)->(tax:00CZ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008Z),(ann:00AZ),(tax:00CZ)->(sum:00EZ)
# {reads}->{annable-taxable} || (reads-14:000W)->(annable-taxable:008a)
# {annable}->{ann} || (annable-taxable:008a)->(ann:00Aa)
# {taxable}->{tax} || (annable-taxable:008a)->(tax:00Ca)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008a),(ann:00Aa),(tax:00Ca)->(sum:00Ea)
# {reads}->{annable-taxable} || (15-reads:000X)->(annable-taxable:008b)
# {annable}->{ann} || (annable-taxable:008b)->(ann:00Ab)
# {taxable}->{tax} || (annable-taxable:008b)->(tax:00Cb)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008b),(ann:00Ab),(tax:00Cb)->(sum:00Eb)
# {reads}->{annable-taxable} || (16-reads:000Y)->(annable-taxable:008c)
# {annable}->{ann} || (annable-taxable:008c)->(ann:00Ac)
# {taxable}->{tax} || (annable-taxable:008c)->(tax:00Cc)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008c),(ann:00Ac),(tax:00Cc)->(sum:00Ec)
# {reads}->{annable-taxable} || (17-reads:000Z)->(annable-taxable:008d)
# {annable}->{ann} || (annable-taxable:008d)->(ann:00Ad)
# {taxable}->{tax} || (annable-taxable:008d)->(tax:00Cd)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008d),(ann:00Ad),(tax:00Cd)->(sum:00Ed)
# {reads}->{annable-taxable} || (reads-18:000a)->(annable-taxable:008e)
# {annable}->{ann} || (annable-taxable:008e)->(ann:00Ae)
# {taxable}->{tax} || (annable-taxable:008e)->(tax:00Ce)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008e),(ann:00Ae),(tax:00Ce)->(sum:00Ee)
# {reads}->{annable-taxable} || (reads-19:000b)->(annable-taxable:008f)
# {annable}->{ann} || (annable-taxable:008f)->(ann:00Af)
# {taxable}->{tax} || (annable-taxable:008f)->(tax:00Cf)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008f),(ann:00Af),(tax:00Cf)->(sum:00Ef)
# {reads}->{annable-taxable} || (reads-20:000c)->(annable-taxable:008g)
# {annable}->{ann} || (annable-taxable:008g)->(ann:00Ag)
# {taxable}->{tax} || (annable-taxable:008g)->(tax:00Cg)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008g),(ann:00Ag),(tax:00Cg)->(sum:00Eg)
# {reads}->{annable-taxable} || (21-reads:000d)->(annable-taxable:008h)
# {annable}->{ann} || (annable-taxable:008h)->(ann:00Ah)
# {taxable}->{tax} || (annable-taxable:008h)->(tax:00Ch)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008h),(ann:00Ah),(tax:00Ch)->(sum:00Eh)
# {reads}->{annable-taxable} || (22-reads:000e)->(annable-taxable:008i)
# {annable}->{ann} || (annable-taxable:008i)->(ann:00Ai)
# {taxable}->{tax} || (annable-taxable:008i)->(tax:00Ci)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008i),(ann:00Ai),(tax:00Ci)->(sum:00Ei)
# {reads}->{annable-taxable} || (23-reads:000f)->(annable-taxable:008j)
# {annable}->{ann} || (annable-taxable:008j)->(ann:00Aj)
# {taxable}->{tax} || (annable-taxable:008j)->(tax:00Cj)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008j),(ann:00Aj),(tax:00Cj)->(sum:00Ej)
# {reads}->{annable-taxable} || (reads-24:000g)->(annable-taxable:008k)
# {annable}->{ann} || (annable-taxable:008k)->(ann:00Ak)
# {taxable}->{tax} || (annable-taxable:008k)->(tax:00Ck)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008k),(ann:00Ak),(tax:00Ck)->(sum:00Ek)
# {reads}->{annable-taxable} || (25-reads:000h)->(annable-taxable:008l)
# {annable}->{ann} || (annable-taxable:008l)->(ann:00Al)
# {taxable}->{tax} || (annable-taxable:008l)->(tax:00Cl)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008l),(ann:00Al),(tax:00Cl)->(sum:00El)
# {reads}->{annable-taxable} || (26-reads:000i)->(annable-taxable:008m)
# {annable}->{ann} || (annable-taxable:008m)->(ann:00Am)
# {taxable}->{tax} || (annable-taxable:008m)->(tax:00Cm)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008m),(ann:00Am),(tax:00Cm)->(sum:00Em)
# {reads}->{annable-taxable} || (27-reads:000j)->(annable-taxable:008n)
# {annable}->{ann} || (annable-taxable:008n)->(ann:00An)
# {taxable}->{tax} || (annable-taxable:008n)->(tax:00Cn)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008n),(ann:00An),(tax:00Cn)->(sum:00En)
# {reads}->{annable-taxable} || (28-reads:000k)->(annable-taxable:008o)
# {annable}->{ann} || (annable-taxable:008o)->(ann:00Ao)
# {taxable}->{tax} || (annable-taxable:008o)->(tax:00Co)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008o),(ann:00Ao),(tax:00Co)->(sum:00Eo)
# {reads}->{annable-taxable} || (29-reads:000l)->(annable-taxable:008p)
# {annable}->{ann} || (annable-taxable:008p)->(ann:00Ap)
# {taxable}->{tax} || (annable-taxable:008p)->(tax:00Cp)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008p),(ann:00Ap),(tax:00Cp)->(sum:00Ep)
# {reads}->{annable-taxable} || (30-reads:000m)->(annable-taxable:008q)
# {annable}->{ann} || (annable-taxable:008q)->(ann:00Aq)
# {taxable}->{tax} || (annable-taxable:008q)->(tax:00Cq)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008q),(ann:00Aq),(tax:00Cq)->(sum:00Eq)
# {reads}->{annable-taxable} || (31-reads:000n)->(annable-taxable:008r)
# {annable}->{ann} || (annable-taxable:008r)->(ann:00Ar)
# {taxable}->{tax} || (annable-taxable:008r)->(tax:00Cr)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008r),(ann:00Ar),(tax:00Cr)->(sum:00Er)
# {reads}->{annable-taxable} || (reads-32:000o)->(annable-taxable:008s)
# {annable}->{ann} || (annable-taxable:008s)->(ann:00As)
# {taxable}->{tax} || (annable-taxable:008s)->(tax:00Cs)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008s),(ann:00As),(tax:00Cs)->(sum:00Es)
# {reads}->{annable-taxable} || (reads-33:000p)->(annable-taxable:008t)
# {annable}->{ann} || (annable-taxable:008t)->(ann:00At)
# {taxable}->{tax} || (annable-taxable:008t)->(tax:00Ct)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008t),(ann:00At),(tax:00Ct)->(sum:00Et)
# {reads}->{annable-taxable} || (34-reads:000q)->(annable-taxable:008u)
# {annable}->{ann} || (annable-taxable:008u)->(ann:00Au)
# {taxable}->{tax} || (annable-taxable:008u)->(tax:00Cu)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008u),(ann:00Au),(tax:00Cu)->(sum:00Eu)
# {reads}->{annable-taxable} || (35-reads:000r)->(annable-taxable:008v)
# {annable}->{ann} || (annable-taxable:008v)->(ann:00Av)
# {taxable}->{tax} || (annable-taxable:008v)->(tax:00Cv)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008v),(ann:00Av),(tax:00Cv)->(sum:00Ev)
# {reads}->{annable-taxable} || (36-reads:000s)->(annable-taxable:008w)
# {annable}->{ann} || (annable-taxable:008w)->(ann:00Aw)
# {taxable}->{tax} || (annable-taxable:008w)->(tax:00Cw)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008w),(ann:00Aw),(tax:00Cw)->(sum:00Ew)
# {reads}->{annable-taxable} || (reads-37:000t)->(annable-taxable:008x)
# {annable}->{ann} || (annable-taxable:008x)->(ann:00Ax)
# {taxable}->{tax} || (annable-taxable:008x)->(tax:00Cx)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008x),(ann:00Ax),(tax:00Cx)->(sum:00Ex)
# {reads}->{annable-taxable} || (38-reads:000u)->(annable-taxable:008y)
# {annable}->{ann} || (annable-taxable:008y)->(ann:00Ay)
# {taxable}->{tax} || (annable-taxable:008y)->(tax:00Cy)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008y),(ann:00Ay),(tax:00Cy)->(sum:00Ey)
# {reads}->{annable-taxable} || (39-reads:000v)->(annable-taxable:008z)
# {annable}->{ann} || (annable-taxable:008z)->(ann:00Az)
# {taxable}->{tax} || (annable-taxable:008z)->(tax:00Cz)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008z),(ann:00Az),(tax:00Cz)->(sum:00Ez)
# {reads}->{annable-taxable} || (40-reads:000w)->(annable-taxable:008-)
# {annable}->{ann} || (annable-taxable:008-)->(ann:00A-)
# {taxable}->{tax} || (annable-taxable:008-)->(tax:00C-)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008-),(ann:00A-),(tax:00C-)->(sum:00E-)
# {reads}->{annable-taxable} || (41-reads:000x)->(annable-taxable:008_)
# {annable}->{ann} || (annable-taxable:008_)->(ann:00A_)
# {taxable}->{tax} || (annable-taxable:008_)->(tax:00C_)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:008_),(ann:00A_),(tax:00C_)->(sum:00E_)
# {reads}->{annable-taxable} || (42-reads:000y)->(annable-taxable:0090)
# {annable}->{ann} || (annable-taxable:0090)->(ann:00B0)
# {taxable}->{tax} || (annable-taxable:0090)->(tax:00D0)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0090),(ann:00B0),(tax:00D0)->(sum:00F0)
# {reads}->{annable-taxable} || (43-reads:000z)->(annable-taxable:0091)
# {annable}->{ann} || (annable-taxable:0091)->(ann:00B1)
# {taxable}->{tax} || (annable-taxable:0091)->(tax:00D1)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0091),(ann:00B1),(tax:00D1)->(sum:00F1)
# {reads}->{annable-taxable} || (44-reads:000-)->(annable-taxable:0092)
# {annable}->{ann} || (annable-taxable:0092)->(ann:00B2)
# {taxable}->{tax} || (annable-taxable:0092)->(tax:00D2)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0092),(ann:00B2),(tax:00D2)->(sum:00F2)
# {reads}->{annable-taxable} || (reads-45:000_)->(annable-taxable:0093)
# {annable}->{ann} || (annable-taxable:0093)->(ann:00B3)
# {taxable}->{tax} || (annable-taxable:0093)->(tax:00D3)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0093),(ann:00B3),(tax:00D3)->(sum:00F3)
# {reads}->{annable-taxable} || (46-reads:0010)->(annable-taxable:0094)
# {annable}->{ann} || (annable-taxable:0094)->(ann:00B4)
# {taxable}->{tax} || (annable-taxable:0094)->(tax:00D4)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0094),(ann:00B4),(tax:00D4)->(sum:00F4)
# {reads}->{annable-taxable} || (reads-47:0011)->(annable-taxable:0095)
# {annable}->{ann} || (annable-taxable:0095)->(ann:00B5)
# {taxable}->{tax} || (annable-taxable:0095)->(tax:00D5)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0095),(ann:00B5),(tax:00D5)->(sum:00F5)
# {reads}->{annable-taxable} || (48-reads:0012)->(annable-taxable:0096)
# {annable}->{ann} || (annable-taxable:0096)->(ann:00B6)
# {taxable}->{tax} || (annable-taxable:0096)->(tax:00D6)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0096),(ann:00B6),(tax:00D6)->(sum:00F6)
# {reads}->{annable-taxable} || (reads-49:0013)->(annable-taxable:0097)
# {annable}->{ann} || (annable-taxable:0097)->(ann:00B7)
# {taxable}->{tax} || (annable-taxable:0097)->(tax:00D7)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0097),(ann:00B7),(tax:00D7)->(sum:00F7)
# {reads}->{annable-taxable} || (50-reads:0014)->(annable-taxable:0098)
# {annable}->{ann} || (annable-taxable:0098)->(ann:00B8)
# {taxable}->{tax} || (annable-taxable:0098)->(tax:00D8)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0098),(ann:00B8),(tax:00D8)->(sum:00F8)
# {reads}->{annable-taxable} || (51-reads:0015)->(annable-taxable:0099)
# {annable}->{ann} || (annable-taxable:0099)->(ann:00B9)
# {taxable}->{tax} || (annable-taxable:0099)->(tax:00D9)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:0099),(ann:00B9),(tax:00D9)->(sum:00F9)
# {reads}->{annable-taxable} || (52-reads:0016)->(annable-taxable:009A)
# {annable}->{ann} || (annable-taxable:009A)->(ann:00BA)
# {taxable}->{tax} || (annable-taxable:009A)->(tax:00DA)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009A),(ann:00BA),(tax:00DA)->(sum:00FA)
# {reads}->{annable-taxable} || (53-reads:0017)->(annable-taxable:009B)
# {annable}->{ann} || (annable-taxable:009B)->(ann:00BB)
# {taxable}->{tax} || (annable-taxable:009B)->(tax:00DB)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009B),(ann:00BB),(tax:00DB)->(sum:00FB)
# {reads}->{annable-taxable} || (54-reads:0018)->(annable-taxable:009C)
# {annable}->{ann} || (annable-taxable:009C)->(ann:00BC)
# {taxable}->{tax} || (annable-taxable:009C)->(tax:00DC)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009C),(ann:00BC),(tax:00DC)->(sum:00FC)
# {reads}->{annable-taxable} || (reads-55:0019)->(annable-taxable:009D)
# {annable}->{ann} || (annable-taxable:009D)->(ann:00BD)
# {taxable}->{tax} || (annable-taxable:009D)->(tax:00DD)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009D),(ann:00BD),(tax:00DD)->(sum:00FD)
# {reads}->{annable-taxable} || (56-reads:001A)->(annable-taxable:009E)
# {annable}->{ann} || (annable-taxable:009E)->(ann:00BE)
# {taxable}->{tax} || (annable-taxable:009E)->(tax:00DE)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009E),(ann:00BE),(tax:00DE)->(sum:00FE)
# {reads}->{annable-taxable} || (57-reads:001B)->(annable-taxable:009F)
# {annable}->{ann} || (annable-taxable:009F)->(ann:00BF)
# {taxable}->{tax} || (annable-taxable:009F)->(tax:00DF)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009F),(ann:00BF),(tax:00DF)->(sum:00FF)
# {reads}->{annable-taxable} || (58-reads:001C)->(annable-taxable:009G)
# {annable}->{ann} || (annable-taxable:009G)->(ann:00BG)
# {taxable}->{tax} || (annable-taxable:009G)->(tax:00DG)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009G),(ann:00BG),(tax:00DG)->(sum:00FG)
# {reads}->{annable-taxable} || (reads-59:001D)->(annable-taxable:009H)
# {annable}->{ann} || (annable-taxable:009H)->(ann:00BH)
# {taxable}->{tax} || (annable-taxable:009H)->(tax:00DH)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009H),(ann:00BH),(tax:00DH)->(sum:00FH)
# {reads}->{annable-taxable} || (60-reads:001E)->(annable-taxable:009I)
# {annable}->{ann} || (annable-taxable:009I)->(ann:00BI)
# {taxable}->{tax} || (annable-taxable:009I)->(tax:00DI)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009I),(ann:00BI),(tax:00DI)->(sum:00FI)
# {reads}->{annable-taxable} || (reads-61:001F)->(annable-taxable:009J)
# {annable}->{ann} || (annable-taxable:009J)->(ann:00BJ)
# {taxable}->{tax} || (annable-taxable:009J)->(tax:00DJ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009J),(ann:00BJ),(tax:00DJ)->(sum:00FJ)
# {reads}->{annable-taxable} || (62-reads:001G)->(annable-taxable:009K)
# {annable}->{ann} || (annable-taxable:009K)->(ann:00BK)
# {taxable}->{tax} || (annable-taxable:009K)->(tax:00DK)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009K),(ann:00BK),(tax:00DK)->(sum:00FK)
# {reads}->{annable-taxable} || (63-reads:001H)->(annable-taxable:009L)
# {annable}->{ann} || (annable-taxable:009L)->(ann:00BL)
# {taxable}->{tax} || (annable-taxable:009L)->(tax:00DL)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009L),(ann:00BL),(tax:00DL)->(sum:00FL)
# {reads}->{annable-taxable} || (64-reads:001I)->(annable-taxable:009M)
# {annable}->{ann} || (annable-taxable:009M)->(ann:00BM)
# {taxable}->{tax} || (annable-taxable:009M)->(tax:00DM)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009M),(ann:00BM),(tax:00DM)->(sum:00FM)
# {reads}->{annable-taxable} || (reads-65:001J)->(annable-taxable:009N)
# {annable}->{ann} || (annable-taxable:009N)->(ann:00BN)
# {taxable}->{tax} || (annable-taxable:009N)->(tax:00DN)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009N),(ann:00BN),(tax:00DN)->(sum:00FN)
# {reads}->{annable-taxable} || (66-reads:001K)->(annable-taxable:009O)
# {annable}->{ann} || (annable-taxable:009O)->(ann:00BO)
# {taxable}->{tax} || (annable-taxable:009O)->(tax:00DO)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009O),(ann:00BO),(tax:00DO)->(sum:00FO)
# {reads}->{annable-taxable} || (67-reads:001L)->(annable-taxable:009P)
# {annable}->{ann} || (annable-taxable:009P)->(ann:00BP)
# {taxable}->{tax} || (annable-taxable:009P)->(tax:00DP)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009P),(ann:00BP),(tax:00DP)->(sum:00FP)
# {reads}->{annable-taxable} || (68-reads:001M)->(annable-taxable:009Q)
# {annable}->{ann} || (annable-taxable:009Q)->(ann:00BQ)
# {taxable}->{tax} || (annable-taxable:009Q)->(tax:00DQ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009Q),(ann:00BQ),(tax:00DQ)->(sum:00FQ)
# {reads}->{annable-taxable} || (69-reads:001N)->(annable-taxable:009R)
# {annable}->{ann} || (annable-taxable:009R)->(ann:00BR)
# {taxable}->{tax} || (annable-taxable:009R)->(tax:00DR)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009R),(ann:00BR),(tax:00DR)->(sum:00FR)
# {reads}->{annable-taxable} || (reads-70:001O)->(annable-taxable:009S)
# {annable}->{ann} || (annable-taxable:009S)->(ann:00BS)
# {taxable}->{tax} || (annable-taxable:009S)->(tax:00DS)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009S),(ann:00BS),(tax:00DS)->(sum:00FS)
# {reads}->{annable-taxable} || (71-reads:001P)->(annable-taxable:009T)
# {annable}->{ann} || (annable-taxable:009T)->(ann:00BT)
# {taxable}->{tax} || (annable-taxable:009T)->(tax:00DT)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009T),(ann:00BT),(tax:00DT)->(sum:00FT)
# {reads}->{annable-taxable} || (reads-72:001Q)->(annable-taxable:009U)
# {annable}->{ann} || (annable-taxable:009U)->(ann:00BU)
# {taxable}->{tax} || (annable-taxable:009U)->(tax:00DU)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009U),(ann:00BU),(tax:00DU)->(sum:00FU)
# {reads}->{annable-taxable} || (73-reads:001R)->(annable-taxable:009V)
# {annable}->{ann} || (annable-taxable:009V)->(ann:00BV)
# {taxable}->{tax} || (annable-taxable:009V)->(tax:00DV)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009V),(ann:00BV),(tax:00DV)->(sum:00FV)
# {reads}->{annable-taxable} || (74-reads:001S)->(annable-taxable:009W)
# {annable}->{ann} || (annable-taxable:009W)->(ann:00BW)
# {taxable}->{tax} || (annable-taxable:009W)->(tax:00DW)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009W),(ann:00BW),(tax:00DW)->(sum:00FW)
# {reads}->{annable-taxable} || (reads-75:001T)->(annable-taxable:009X)
# {annable}->{ann} || (annable-taxable:009X)->(ann:00BX)
# {taxable}->{tax} || (annable-taxable:009X)->(tax:00DX)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009X),(ann:00BX),(tax:00DX)->(sum:00FX)
# {reads}->{annable-taxable} || (76-reads:001U)->(annable-taxable:009Y)
# {annable}->{ann} || (annable-taxable:009Y)->(ann:00BY)
# {taxable}->{tax} || (annable-taxable:009Y)->(tax:00DY)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009Y),(ann:00BY),(tax:00DY)->(sum:00FY)
# {reads}->{annable-taxable} || (reads-77:001V)->(annable-taxable:009Z)
# {annable}->{ann} || (annable-taxable:009Z)->(ann:00BZ)
# {taxable}->{tax} || (annable-taxable:009Z)->(tax:00DZ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009Z),(ann:00BZ),(tax:00DZ)->(sum:00FZ)
# {reads}->{annable-taxable} || (reads-78:001W)->(annable-taxable:009a)
# {annable}->{ann} || (annable-taxable:009a)->(ann:00Ba)
# {taxable}->{tax} || (annable-taxable:009a)->(tax:00Da)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009a),(ann:00Ba),(tax:00Da)->(sum:00Fa)
# {reads}->{annable-taxable} || (79-reads:001X)->(annable-taxable:009b)
# {annable}->{ann} || (annable-taxable:009b)->(ann:00Bb)
# {taxable}->{tax} || (annable-taxable:009b)->(tax:00Db)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009b),(ann:00Bb),(tax:00Db)->(sum:00Fb)
# {reads}->{annable-taxable} || (80-reads:001Y)->(annable-taxable:009c)
# {annable}->{ann} || (annable-taxable:009c)->(ann:00Bc)
# {taxable}->{tax} || (annable-taxable:009c)->(tax:00Dc)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009c),(ann:00Bc),(tax:00Dc)->(sum:00Fc)
# {reads}->{annable-taxable} || (81-reads:001Z)->(annable-taxable:009d)
# {annable}->{ann} || (annable-taxable:009d)->(ann:00Bd)
# {taxable}->{tax} || (annable-taxable:009d)->(tax:00Dd)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009d),(ann:00Bd),(tax:00Dd)->(sum:00Fd)
# {reads}->{annable-taxable} || (82-reads:001a)->(annable-taxable:009e)
# {annable}->{ann} || (annable-taxable:009e)->(ann:00Be)
# {taxable}->{tax} || (annable-taxable:009e)->(tax:00De)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009e),(ann:00Be),(tax:00De)->(sum:00Fe)
# {reads}->{annable-taxable} || (83-reads:001b)->(annable-taxable:009f)
# {annable}->{ann} || (annable-taxable:009f)->(ann:00Bf)
# {taxable}->{tax} || (annable-taxable:009f)->(tax:00Df)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009f),(ann:00Bf),(tax:00Df)->(sum:00Ff)
# {reads}->{annable-taxable} || (reads-84:001c)->(annable-taxable:009g)
# {annable}->{ann} || (annable-taxable:009g)->(ann:00Bg)
# {taxable}->{tax} || (annable-taxable:009g)->(tax:00Dg)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009g),(ann:00Bg),(tax:00Dg)->(sum:00Fg)
# {reads}->{annable-taxable} || (85-reads:001d)->(annable-taxable:009h)
# {annable}->{ann} || (annable-taxable:009h)->(ann:00Bh)
# {taxable}->{tax} || (annable-taxable:009h)->(tax:00Dh)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009h),(ann:00Bh),(tax:00Dh)->(sum:00Fh)
# {reads}->{annable-taxable} || (86-reads:001e)->(annable-taxable:009i)
# {annable}->{ann} || (annable-taxable:009i)->(ann:00Bi)
# {taxable}->{tax} || (annable-taxable:009i)->(tax:00Di)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009i),(ann:00Bi),(tax:00Di)->(sum:00Fi)
# {reads}->{annable-taxable} || (87-reads:001f)->(annable-taxable:009j)
# {annable}->{ann} || (annable-taxable:009j)->(ann:00Bj)
# {taxable}->{tax} || (annable-taxable:009j)->(tax:00Dj)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009j),(ann:00Bj),(tax:00Dj)->(sum:00Fj)
# {reads}->{annable-taxable} || (reads-88:001g)->(annable-taxable:009k)
# {annable}->{ann} || (annable-taxable:009k)->(ann:00Bk)
# {taxable}->{tax} || (annable-taxable:009k)->(tax:00Dk)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009k),(ann:00Bk),(tax:00Dk)->(sum:00Fk)
# {reads}->{annable-taxable} || (89-reads:001h)->(annable-taxable:009l)
# {annable}->{ann} || (annable-taxable:009l)->(ann:00Bl)
# {taxable}->{tax} || (annable-taxable:009l)->(tax:00Dl)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009l),(ann:00Bl),(tax:00Dl)->(sum:00Fl)
# {reads}->{annable-taxable} || (90-reads:001i)->(annable-taxable:009m)
# {annable}->{ann} || (annable-taxable:009m)->(ann:00Bm)
# {taxable}->{tax} || (annable-taxable:009m)->(tax:00Dm)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009m),(ann:00Bm),(tax:00Dm)->(sum:00Fm)
# {reads}->{annable-taxable} || (91-reads:001j)->(annable-taxable:009n)
# {annable}->{ann} || (annable-taxable:009n)->(ann:00Bn)
# {taxable}->{tax} || (annable-taxable:009n)->(tax:00Dn)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009n),(ann:00Bn),(tax:00Dn)->(sum:00Fn)
# {reads}->{annable-taxable} || (reads-92:001k)->(annable-taxable:009o)
# {annable}->{ann} || (annable-taxable:009o)->(ann:00Bo)
# {taxable}->{tax} || (annable-taxable:009o)->(tax:00Do)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009o),(ann:00Bo),(tax:00Do)->(sum:00Fo)
# {reads}->{annable-taxable} || (93-reads:001l)->(annable-taxable:009p)
# {annable}->{ann} || (annable-taxable:009p)->(ann:00Bp)
# {taxable}->{tax} || (annable-taxable:009p)->(tax:00Dp)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009p),(ann:00Bp),(tax:00Dp)->(sum:00Fp)
# {reads}->{annable-taxable} || (94-reads:001m)->(annable-taxable:009q)
# {annable}->{ann} || (annable-taxable:009q)->(ann:00Bq)
# {taxable}->{tax} || (annable-taxable:009q)->(tax:00Dq)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009q),(ann:00Bq),(tax:00Dq)->(sum:00Fq)
# {reads}->{annable-taxable} || (reads-95:001n)->(annable-taxable:009r)
# {annable}->{ann} || (annable-taxable:009r)->(ann:00Br)
# {taxable}->{tax} || (annable-taxable:009r)->(tax:00Dr)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009r),(ann:00Br),(tax:00Dr)->(sum:00Fr)
# {reads}->{annable-taxable} || (reads-96:001o)->(annable-taxable:009s)
# {annable}->{ann} || (annable-taxable:009s)->(ann:00Bs)
# {taxable}->{tax} || (annable-taxable:009s)->(tax:00Ds)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009s),(ann:00Bs),(tax:00Ds)->(sum:00Fs)
# {reads}->{annable-taxable} || (97-reads:001p)->(annable-taxable:009t)
# {annable}->{ann} || (annable-taxable:009t)->(ann:00Bt)
# {taxable}->{tax} || (annable-taxable:009t)->(tax:00Dt)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009t),(ann:00Bt),(tax:00Dt)->(sum:00Ft)
# {reads}->{annable-taxable} || (98-reads:001q)->(annable-taxable:009u)
# {annable}->{ann} || (annable-taxable:009u)->(ann:00Bu)
# {taxable}->{tax} || (annable-taxable:009u)->(tax:00Du)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009u),(ann:00Bu),(tax:00Du)->(sum:00Fu)
# {reads}->{annable-taxable} || (99-reads:001r)->(annable-taxable:009v)
# {annable}->{ann} || (annable-taxable:009v)->(ann:00Bv)
# {taxable}->{tax} || (annable-taxable:009v)->(tax:00Dv)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009v),(ann:00Bv),(tax:00Dv)->(sum:00Fv)
# {reads}->{annable-taxable} || (100-reads:001s)->(annable-taxable:009w)
# {annable}->{ann} || (annable-taxable:009w)->(ann:00Bw)
# {taxable}->{tax} || (annable-taxable:009w)->(tax:00Dw)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009w),(ann:00Bw),(tax:00Dw)->(sum:00Fw)
# {reads}->{annable-taxable} || (101-reads:001t)->(annable-taxable:009x)
# {annable}->{ann} || (annable-taxable:009x)->(ann:00Bx)
# {taxable}->{tax} || (annable-taxable:009x)->(tax:00Dx)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009x),(ann:00Bx),(tax:00Dx)->(sum:00Fx)
# {reads}->{annable-taxable} || (102-reads:001u)->(annable-taxable:009y)
# {annable}->{ann} || (annable-taxable:009y)->(ann:00By)
# {taxable}->{tax} || (annable-taxable:009y)->(tax:00Dy)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009y),(ann:00By),(tax:00Dy)->(sum:00Fy)
# {reads}->{annable-taxable} || (103-reads:001v)->(annable-taxable:009z)
# {annable}->{ann} || (annable-taxable:009z)->(ann:00Bz)
# {taxable}->{tax} || (annable-taxable:009z)->(tax:00Dz)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009z),(ann:00Bz),(tax:00Dz)->(sum:00Fz)
# {reads}->{annable-taxable} || (reads-104:001w)->(annable-taxable:009-)
# {annable}->{ann} || (annable-taxable:009-)->(ann:00B-)
# {taxable}->{tax} || (annable-taxable:009-)->(tax:00D-)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009-),(ann:00B-),(tax:00D-)->(sum:00F-)
# {reads}->{annable-taxable} || (105-reads:001x)->(annable-taxable:009_)
# {annable}->{ann} || (annable-taxable:009_)->(ann:00B_)
# {taxable}->{tax} || (annable-taxable:009_)->(tax:00D_)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:009_),(ann:00B_),(tax:00D_)->(sum:00F_)
# {reads}->{annable-taxable} || (reads-106:001y)->(annable-taxable:00A0)
# {annable}->{ann} || (annable-taxable:00A0)->(ann:00C0)
# {taxable}->{tax} || (annable-taxable:00A0)->(tax:00E0)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A0),(ann:00C0),(tax:00E0)->(sum:00G0)
# {reads}->{annable-taxable} || (107-reads:001z)->(annable-taxable:00A1)
# {annable}->{ann} || (annable-taxable:00A1)->(ann:00C1)
# {taxable}->{tax} || (annable-taxable:00A1)->(tax:00E1)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A1),(ann:00C1),(tax:00E1)->(sum:00G1)
# {reads}->{annable-taxable} || (reads-108:001-)->(annable-taxable:00A2)
# {annable}->{ann} || (annable-taxable:00A2)->(ann:00C2)
# {taxable}->{tax} || (annable-taxable:00A2)->(tax:00E2)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A2),(ann:00C2),(tax:00E2)->(sum:00G2)
# {reads}->{annable-taxable} || (reads-109:001_)->(annable-taxable:00A3)
# {annable}->{ann} || (annable-taxable:00A3)->(ann:00C3)
# {taxable}->{tax} || (annable-taxable:00A3)->(tax:00E3)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A3),(ann:00C3),(tax:00E3)->(sum:00G3)
# {reads}->{annable-taxable} || (reads-110:0020)->(annable-taxable:00A4)
# {annable}->{ann} || (annable-taxable:00A4)->(ann:00C4)
# {taxable}->{tax} || (annable-taxable:00A4)->(tax:00E4)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A4),(ann:00C4),(tax:00E4)->(sum:00G4)
# {reads}->{annable-taxable} || (111-reads:0021)->(annable-taxable:00A5)
# {annable}->{ann} || (annable-taxable:00A5)->(ann:00C5)
# {taxable}->{tax} || (annable-taxable:00A5)->(tax:00E5)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A5),(ann:00C5),(tax:00E5)->(sum:00G5)
# {reads}->{annable-taxable} || (112-reads:0022)->(annable-taxable:00A6)
# {annable}->{ann} || (annable-taxable:00A6)->(ann:00C6)
# {taxable}->{tax} || (annable-taxable:00A6)->(tax:00E6)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A6),(ann:00C6),(tax:00E6)->(sum:00G6)
# {reads}->{annable-taxable} || (113-reads:0023)->(annable-taxable:00A7)
# {annable}->{ann} || (annable-taxable:00A7)->(ann:00C7)
# {taxable}->{tax} || (annable-taxable:00A7)->(tax:00E7)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A7),(ann:00C7),(tax:00E7)->(sum:00G7)
# {reads}->{annable-taxable} || (114-reads:0024)->(annable-taxable:00A8)
# {annable}->{ann} || (annable-taxable:00A8)->(ann:00C8)
# {taxable}->{tax} || (annable-taxable:00A8)->(tax:00E8)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A8),(ann:00C8),(tax:00E8)->(sum:00G8)
# {reads}->{annable-taxable} || (115-reads:0025)->(annable-taxable:00A9)
# {annable}->{ann} || (annable-taxable:00A9)->(ann:00C9)
# {taxable}->{tax} || (annable-taxable:00A9)->(tax:00E9)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00A9),(ann:00C9),(tax:00E9)->(sum:00G9)
# {reads}->{annable-taxable} || (116-reads:0026)->(annable-taxable:00AA)
# {annable}->{ann} || (annable-taxable:00AA)->(ann:00CA)
# {taxable}->{tax} || (annable-taxable:00AA)->(tax:00EA)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AA),(ann:00CA),(tax:00EA)->(sum:00GA)
# {reads}->{annable-taxable} || (117-reads:0027)->(annable-taxable:00AB)
# {annable}->{ann} || (annable-taxable:00AB)->(ann:00CB)
# {taxable}->{tax} || (annable-taxable:00AB)->(tax:00EB)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AB),(ann:00CB),(tax:00EB)->(sum:00GB)
# {reads}->{annable-taxable} || (118-reads:0028)->(annable-taxable:00AC)
# {annable}->{ann} || (annable-taxable:00AC)->(ann:00CC)
# {taxable}->{tax} || (annable-taxable:00AC)->(tax:00EC)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AC),(ann:00CC),(tax:00EC)->(sum:00GC)
# {reads}->{annable-taxable} || (119-reads:0029)->(annable-taxable:00AD)
# {annable}->{ann} || (annable-taxable:00AD)->(ann:00CD)
# {taxable}->{tax} || (annable-taxable:00AD)->(tax:00ED)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AD),(ann:00CD),(tax:00ED)->(sum:00GD)
# {reads}->{annable-taxable} || (120-reads:002A)->(annable-taxable:00AE)
# {annable}->{ann} || (annable-taxable:00AE)->(ann:00CE)
# {taxable}->{tax} || (annable-taxable:00AE)->(tax:00EE)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AE),(ann:00CE),(tax:00EE)->(sum:00GE)
# {reads}->{annable-taxable} || (reads-121:002B)->(annable-taxable:00AF)
# {annable}->{ann} || (annable-taxable:00AF)->(ann:00CF)
# {taxable}->{tax} || (annable-taxable:00AF)->(tax:00EF)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AF),(ann:00CF),(tax:00EF)->(sum:00GF)
# {reads}->{annable-taxable} || (122-reads:002C)->(annable-taxable:00AG)
# {annable}->{ann} || (annable-taxable:00AG)->(ann:00CG)
# {taxable}->{tax} || (annable-taxable:00AG)->(tax:00EG)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AG),(ann:00CG),(tax:00EG)->(sum:00GG)
# {reads}->{annable-taxable} || (123-reads:002D)->(annable-taxable:00AH)
# {annable}->{ann} || (annable-taxable:00AH)->(ann:00CH)
# {taxable}->{tax} || (annable-taxable:00AH)->(tax:00EH)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AH),(ann:00CH),(tax:00EH)->(sum:00GH)
# {reads}->{annable-taxable} || (124-reads:002E)->(annable-taxable:00AI)
# {annable}->{ann} || (annable-taxable:00AI)->(ann:00CI)
# {taxable}->{tax} || (annable-taxable:00AI)->(tax:00EI)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AI),(ann:00CI),(tax:00EI)->(sum:00GI)
# {reads}->{annable-taxable} || (125-reads:002F)->(annable-taxable:00AJ)
# {annable}->{ann} || (annable-taxable:00AJ)->(ann:00CJ)
# {taxable}->{tax} || (annable-taxable:00AJ)->(tax:00EJ)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AJ),(ann:00CJ),(tax:00EJ)->(sum:00GJ)
# {reads}->{annable-taxable} || (126-reads:002G)->(annable-taxable:00AK)
# {annable}->{ann} || (annable-taxable:00AK)->(ann:00CK)
# {taxable}->{tax} || (annable-taxable:00AK)->(tax:00EK)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AK),(ann:00CK),(tax:00EK)->(sum:00GK)
# {reads}->{annable-taxable} || (127-reads:002H)->(annable-taxable:00AL)
# {annable}->{ann} || (annable-taxable:00AL)->(ann:00CL)
# {taxable}->{tax} || (annable-taxable:00AL)->(tax:00EL)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AL),(ann:00CL),(tax:00EL)->(sum:00GL)
# {reads}->{annable-taxable} || (128-reads:002I)->(annable-taxable:00AM)
# {annable}->{ann} || (annable-taxable:00AM)->(ann:00CM)
# {taxable}->{tax} || (annable-taxable:00AM)->(tax:00EM)
# {annable-taxable},{ann},{tax}->{sum} || (annable-taxable:00AM),(ann:00CM),(tax:00EM)->(sum:00GM)
# {reads-1},{sum},{2-reads},{sum},{3-reads},{sum},{4-reads},{sum},{reads-5},{sum},{6-reads},{sum},{reads-7},{sum},{8-reads},{sum},{reads-9},{sum},{10-reads},{sum},{11-reads},{sum},{12-reads},{sum},{13-reads},{sum},{reads-14},{sum},{15-reads},{sum},{16-reads},{sum},{17-reads},{sum},{reads-18},{sum},{reads-19},{sum},{reads-20},{sum},{21-reads},{sum},{22-reads},{sum},{23-reads},{sum},{reads-24},{sum},{25-reads},{sum},{26-reads},{sum},{27-reads},{sum},{28-reads},{sum},{29-reads},{sum},{30-reads},{sum},{31-reads},{sum},{reads-32},{sum},{reads-33},{sum},{34-reads},{sum},{35-reads},{sum},{36-reads},{sum},{reads-37},{sum},{38-reads},{sum},{39-reads},{sum},{40-reads},{sum},{41-reads},{sum},{42-reads},{sum},{43-reads},{sum},{44-reads},{sum},{reads-45},{sum},{46-reads},{sum},{reads-47},{sum},{48-reads},{sum},{reads-49},{sum},{50-reads},{sum},{51-reads},{sum},{52-reads},{sum},{53-reads},{sum},{54-reads},{sum},{reads-55},{sum},{56-reads},{sum},{57-reads},{sum},{58-reads},{sum},{reads-59},{sum},{60-reads},{sum},{reads-61},{sum},{62-reads},{sum},{63-reads},{sum},{64-reads},{sum},{reads-65},{sum},{66-reads},{sum},{67-reads},{sum},{68-reads},{sum},{69-reads},{sum},{reads-70},{sum},{71-reads},{sum},{reads-72},{sum},{73-reads},{sum},{74-reads},{sum},{reads-75},{sum},{76-reads},{sum},{reads-77},{sum},{reads-78},{sum},{79-reads},{sum},{80-reads},{sum},{81-reads},{sum},{82-reads},{sum},{83-reads},{sum},{reads-84},{sum},{85-reads},{sum},{86-reads},{sum},{87-reads},{sum},{reads-88},{sum},{89-reads},{sum},{90-reads},{sum},{91-reads},{sum},{reads-92},{sum},{93-reads},{sum},{94-reads},{sum},{reads-95},{sum},{reads-96},{sum},{97-reads},{sum},{98-reads},{sum},{99-reads},{sum},{100-reads},{sum},{101-reads},{sum},{102-reads},{sum},{103-reads},{sum},{reads-104},{sum},{105-reads},{sum},{reads-106},{sum},{107-reads},{sum},{reads-108},{sum},{reads-109},{sum},{reads-110},{sum},{111-reads},{sum},{112-reads},{sum},{113-reads},{sum},{114-reads},{sum},{115-reads},{sum},{116-reads},{sum},{117-reads},{sum},{118-reads},{sum},{119-reads},{sum},{120-reads},{sum},{reads-121},{sum},{122-reads},{sum},{123-reads},{sum},{124-reads},{sum},{125-reads},{sum},{126-reads},{sum},{127-reads},{sum},{128-reads},{sum}-> || (reads-1:000J),(sum:00EN),(2-reads:000K),(sum:00EO),(3-reads:000L),(sum:00EP),(4-reads:000M),(sum:00EQ),(reads-5:000N),(sum:00ER),(6-reads:000O),(sum:00ES),(reads-7:000P),(sum:00ET),(8-reads:000Q),(sum:00EU),(reads-9:000R),(sum:00EV),(10-reads:000S),(sum:00EW),(11-reads:000T),(sum:00EX),(12-reads:000U),(sum:00EY),(13-reads:000V),(sum:00EZ),(reads-14:000W),(sum:00Ea),(15-reads:000X),(sum:00Eb),(16-reads:000Y),(sum:00Ec),(17-reads:000Z),(sum:00Ed),(reads-18:000a),(sum:00Ee),(reads-19:000b),(sum:00Ef),(reads-20:000c),(sum:00Eg),(21-reads:000d),(sum:00Eh),(22-reads:000e),(sum:00Ei),(23-reads:000f),(sum:00Ej),(reads-24:000g),(sum:00Ek),(25-reads:000h),(sum:00El),(26-reads:000i),(sum:00Em),(27-reads:000j),(sum:00En),(28-reads:000k),(sum:00Eo),(29-reads:000l),(sum:00Ep),(30-reads:000m),(sum:00Eq),(31-reads:000n),(sum:00Er),(reads-32:000o),(sum:00Es),(reads-33:000p),(sum:00Et),(34-reads:000q),(sum:00Eu),(35-reads:000r),(sum:00Ev),(36-reads:000s),(sum:00Ew),(reads-37:000t),(sum:00Ex),(38-reads:000u),(sum:00Ey),(39-reads:000v),(sum:00Ez),(40-reads:000w),(sum:00E-),(41-reads:000x),(sum:00E_),(42-reads:000y),(sum:00F0),(43-reads:000z),(sum:00F1),(44-reads:000-),(sum:00F2),(reads-45:000_),(sum:00F3),(46-reads:0010),(sum:00F4),(reads-47:0011),(sum:00F5),(48-reads:0012),(sum:00F6),(reads-49:0013),(sum:00F7),(50-reads:0014),(sum:00F8),(51-reads:0015),(sum:00F9),(52-reads:0016),(sum:00FA),(53-reads:0017),(sum:00FB),(54-reads:0018),(sum:00FC),(reads-55:0019),(sum:00FD),(56-reads:001A),(sum:00FE),(57-reads:001B),(sum:00FF),(58-reads:001C),(sum:00FG),(reads-59:001D),(sum:00FH),(60-reads:001E),(sum:00FI),(reads-61:001F),(sum:00FJ),(62-reads:001G),(sum:00FK),(63-reads:001H),(sum:00FL),(64-reads:001I),(sum:00FM),(reads-65:001J),(sum:00FN),(66-reads:001K),(sum:00FO),(67-reads:001L),(sum:00FP) ...
