# %% [markdown]
# for convenience, sync the src code to sockeye so that the container doesn't need to be copied on every change

# %%
from metasmith.coms.ipc import LiveShell
from local.constants import WORKSPACE_ROOT


# host = "sockeye"
# home = f"{host}:~/scratch/metasmith_home"

# host = "cosmos"
# home = f"{host}:/home/tony/workspace/metasmith_home"

# home = f"{WORKSPACE_ROOT}/main/local_mock/cache/local_home"

home = f"{WORKSPACE_ROOT}/docs/source/metasmith_home"

with LiveShell() as shell:
    shell.RegisterOnOut(lambda x: print(x))
    shell.RegisterOnErr(lambda x: print(f"E: {x}"))
    # shell.Exec(f"rsync -ac --progress --mkpath {WORKSPACE_ROOT}/metasmith.sif {home}/metasmith.sif")
    shell.Exec(f"rsync -au --progress --mkpath {WORKSPACE_ROOT}/main/relay_agent/dist/relay {home}/relay/msm_relay")
    shell.Exec(f"rsync -au --progress --mkpath --exclude=__pycache__ {WORKSPACE_ROOT}/src/metasmith/ {home}/dev/metasmith")
    # shell.Exec(f"rsync -au --progress --mkpath --exclude=__pycache__ {WORKSPACE_ROOT}/src/metasmith/nextflow_config {home}/lib/")
# Out:
# sending incremental file list
# sending incremental file list
# example_resources/data/fosmid.xgdb/_metadata/index.yml
#              73 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=29/61)
# example_resources/data/fosmid.xgdb/_metadata/types/genomics.yml
#             796 100%  777.34kB/s    0:00:00 (xfr#2, to-chk=27/61)
# example_resources/data/references.xgdb/
# example_resources/data/references.xgdb/swissprot_bcaa.faa
#           8,785 100%    8.38MB/s    0:00:00 (xfr#3, to-chk=24/61)
# example_resources/data/references.xgdb/_metadata/index.yml
#             195 100%  190.43kB/s    0:00:00 (xfr#4, to-chk=22/61)
# example_resources/data/references.xgdb/_metadata/types/genomics.yml
#             796 100%  777.34kB/s    0:00:00 (xfr#5, to-chk=20/61)
# example_resources/transforms/gene_annotation.xgdb/make_diamond_db.py
#             794 100%  775.39kB/s    0:00:00 (xfr#6, to-chk=17/61)
# example_resources/transforms/gene_annotation.xgdb/_metadata/index.yml
#             159 100%  155.27kB/s    0:00:00 (xfr#7, to-chk=14/61)
# example_resources/transforms/gene_annotation.xgdb/_metadata/types/genomics.yml
#             796 100%  777.34kB/s    0:00:00 (xfr#8, to-chk=12/61)
# example_resources/types/minimal_genomics.yml
#             796 100%  777.34kB/s    0:00:00 (xfr#9, to-chk=10/61)
# models/workflow.py
#          13,145 100%   12.54MB/s    0:00:00 (xfr#10, to-chk=2/61)

# %%
# import logging

# logger = logging.getLogger()
# logger.setLevel(logging.DEBUG)
# logger.handlers.clear()
# logger.addHandler(logging.StreamHandler())
# logger.addHandler(logging.FileHandler(f"./x.log"))

# logger.info("asdf")
# # logger.handlers[0].flush()

# %%
# with LiveShell() as shell:
#     shell.RegisterOnOut(lambda x: print(x))
#     shell.RegisterOnErr(lambda x: print(f"E: {x}"))
#     shell.Exec(f"sleep 300 && echo asdf")

# %%
# with LiveShell() as shell:
#     shell.RegisterOnOut(lambda x: print(x))
#     shell.RegisterOnErr(lambda x: print(f"E: {x}"))
#     shell.Exec(
#         f"""
#         cd /home/tony/workspace/tools/Metasmith/main/local_mock/cache/ws1/run_container
#         apptainer run --no-home --workdir /ws \
#             --bind ./:/ws,.msm:/msm_home \
#             --bind ./:/agent_home \
#             --bind /home/tony/workspace/tools/Metasmith/src/metasmith:/opt/conda/envs/metasmith_env/lib/python3.12/site-packages/metasmith \
#             /home/tony/workspace/tools/Metasmith/metasmith.sif nextflow

#         apptainer run -B ./:/ws
#         cd ~/downloads 
#         mkdir x && cd x
#         /home/tony/workspace/metasmith/lib/msm_bootstrap
#         """
#     )
