# %% [markdown]
# for convenience, sync the src code to sockeye so that the container doesn't need to be copied on every change

# %%
from metasmith.coms.ipc import LiveShell
from local.constants import WORKSPACE_ROOT


# host = "sockeye"
# home = f"{host}:~/scratch/metasmith_home"

# host = "cosmos"
# home = f"{host}:/home/tony/workspace/metasmith_home"

host = "fir"
home = f"{host}:/scratch/phyberos/metasmith"

# home = f"{WORKSPACE_ROOT}/main/local_mock/cache/local_home"

# home = f"{WORKSPACE_ROOT}/main/docs/metasmith_home"

with LiveShell() as shell:
    shell.RegisterOnOut(lambda x: print(x))
    shell.RegisterOnErr(lambda x: print(f"E: {x}"))
    shell.Exec(f"rsync -ac --progress --mkpath {WORKSPACE_ROOT}/metasmith.sif {home}/metasmith.sif")
    shell.Exec(f"rsync -ac --progress --mkpath {WORKSPACE_ROOT}/main/relay_agent/dist/msm_relay {home}/relay/msm_relay")
    shell.Exec(f"rsync -ac --progress --mkpath --exclude=__pycache__ {WORKSPACE_ROOT}/src/metasmith/ {home}/dev/metasmith")
    shell.Exec(f"rsync -ac --progress --mkpath --exclude=__pycache__ {WORKSPACE_ROOT}/src/metasmith/nextflow_config {home}/lib/")
# Out:
# sending incremental file list
# sending incremental file list
# msm_relay
#      31,451,024 100%  245.77MB/s    0:00:00 (xfr#1, to-chk=0/1)
# sending incremental file list
# ./
# __init__.py
#             376 100%    0.00kB/s    0:00:00 (xfr#1, to-chk=124/126)
# __main__.py
#              66 100%   64.45kB/s    0:00:00 (xfr#2, to-chk=123/126)
# agents.py
#          29,795 100%   28.41MB/s    0:00:00 (xfr#3, to-chk=122/126)
# bootstrap.py
#           7,187 100%    6.85MB/s    0:00:00 (xfr#4, to-chk=121/126)
# constants.py
#             429 100%  418.95kB/s    0:00:00 (xfr#5, to-chk=120/126)
# examples.py
#           1,245 100%    1.19MB/s    0:00:00 (xfr#6, to-chk=119/126)
# hashing.py
#           1,443 100%    1.38MB/s    0:00:00 (xfr#7, to-chk=118/126)
# logging.py
#           3,462 100%    3.30MB/s    0:00:00 (xfr#8, to-chk=117/126)
# python_api.py
#             640 100%  625.00kB/s    0:00:00 (xfr#9, to-chk=116/126)
# serialization.py
#           1,522 100%    1.45MB/s    0:00:00 (xfr#10, to-chk=115/126)
# version.txt
#               5 100%    4.88kB/s    0:00:00 (xfr#11, to-chk=114/126)
# bin/
# bin/sbatch
#           1,725 100%   44.33kB/s    0:00:00 (xfr#12, to-chk=107/126)
# bin/squeue
#             764 100%   19.63kB/s    0:00:00 (xfr#13, to-chk=106/126)
# coms/
# coms/__init__.py
#               0 100%    0.00kB/s    0:00:00 (xfr#14, to-chk=105/126)
# coms/api.py
#           1,773 100%   44.40kB/s    0:00:00 (xfr#15, to-chk=104/126)
# coms/cli.py
#           3,152 100%   78.93kB/s    0:00:00 (xfr#16, to-chk=103/126)
# coms/containers.py
#           2,343 100%   58.67kB/s    0:00:00 (xfr#17, to-chk=102/126)
# std/containers.xgdb/prodigal.oci.uri
#              52 100%    1.27kB/s    0:00:00 (xfr#64, to-chk=40/126)
# std/containers.xgdb/qc_table.py
#           1,686 100%   41.16kB/s    0:00:00 (xfr#65, to-chk=39/126)
# std/containers.xgdb/samtools.oci.uri
#              47 100%    1.15kB/s    0:00:00 (xfr#66, to-chk=38/126)
# std/containers.xgdb/script_runner.oci.uri
#              57 100%    1.39kB/s    0:00:00 (xfr#67, to-chk=37/126)
# std/containers.xgdb/seqtk.uri
#              26 100%    0.63kB/s    0:00:00 (xfr#68, to-chk=36/126)
# std/containers.xgdb/trimmomatic.oci.uri
#              33 100%    0.81kB/s    0:00:00 (xfr#69, to-chk=35/126)
# std/containers.xgdb/_metadata/
# std/containers.xgdb/_metadata/index.yml
#           1,373 100%   33.52kB/s    0:00:00 (xfr#70, to-chk=33/126)
# std/containers.xgdb/_metadata/types/
# std/containers.xgdb/_metadata/types/std.yml
#           7,408 100%  180.86kB/s    0:00:00 (xfr#71, to-chk=31/126)
# std/script_runner/
# std/script_runner/Dockerfile
#             222 100%    5.42kB/s    0:00:00 (xfr#72, to-chk=30/126)
# std/transforms.xgdb/
# std/transforms.xgdb/annotations.py
#           3,579 100%   87.38kB/s    0:00:00 (xfr#73, to-chk=29/126)
# std/transforms.xgdb/bakta.py
#           1,599 100%   39.04kB/s    0:00:00 (xfr#74, to-chk=28/126)
# std/transforms.xgdb/bakta_db_full.py
#             861 100%   21.02kB/s    0:00:00 (xfr#75, to-chk=27/126)
# std/transforms.xgdb/bedtools_genomcov.py
#           3,231 100%   78.88kB/s    0:00:00 (xfr#76, to-chk=26/126)
# std/transforms.xgdb/busco.py
#           2,218 100%   54.15kB/s    0:00:00 (xfr#77, to-chk=25/126)
# std/transforms.xgdb/busco_ref.py
#           1,265 100%   30.88kB/s    0:00:00 (xfr#78, to-chk=24/126)
# std/transforms.xgdb/cazy.py
#           2,092 100%   51.07kB/s    0:00:00 (xfr#79, to-chk=23/126)
# std/transforms.xgdb/cazy_ref.py
#             707 100%   17.26kB/s    0:00:00 (xfr#80, to-chk=22/126)
# std/transforms.xgdb/fasterq_long.py
#             956 100%   23.34kB/s    0:00:00 (xfr#81, to-chk=21/126)
# std/transforms.xgdb/fasterq_short.py
#             958 100%   23.39kB/s    0:00:00 (xfr#82, to-chk=20/126)
# std/transforms.xgdb/fastqc.py
#             916 100%   22.36kB/s    0:00:00 (xfr#83, to-chk=19/126)
# std/transforms.xgdb/filtlong_improved.py
#           1,068 100%   26.07kB/s    0:00:00 (xfr#84, to-chk=18/126)
# std/transforms.xgdb/flye.py
#           1,181 100%   28.83kB/s    0:00:00 (xfr#85, to-chk=17/126)
# std/transforms.xgdb/interleave_pe_reads_seqtk.py
#             973 100%   23.75kB/s    0:00:00 (xfr#86, to-chk=16/126)
# std/transforms.xgdb/kofamscan.py
#           1,382 100%   33.74kB/s    0:00:00 (xfr#87, to-chk=15/126)
# std/transforms.xgdb/kofamscan_ko_list.py
#             784 100%   19.14kB/s    0:00:00 (xfr#88, to-chk=14/126)
# std/transforms.xgdb/kofamscan_profiles.py
#             858 100%   20.95kB/s    0:00:00 (xfr#89, to-chk=13/126)
# std/transforms.xgdb/longqc.py
#             915 100%   22.34kB/s    0:00:00 (xfr#90, to-chk=12/126)
# std/transforms.xgdb/megahit.py
#             942 100%   23.00kB/s    0:00:00 (xfr#91, to-chk=11/126)
# std/transforms.xgdb/miniasm.py
#           1,247 100%   30.44kB/s    0:00:00 (xfr#92, to-chk=10/126)
# std/transforms.xgdb/minimap.py
#           3,447 100%   82.10kB/s    0:00:00 (xfr#93, to-chk=9/126)
# std/transforms.xgdb/minimap_self_lr.py
#           1,040 100%   24.77kB/s    0:00:00 (xfr#94, to-chk=8/126)
# std/transforms.xgdb/pilon.py
#           1,712 100%   40.78kB/s    0:00:00 (xfr#95, to-chk=7/126)
# std/transforms.xgdb/prodigal.py
#           1,208 100%   28.77kB/s    0:00:00 (xfr#96, to-chk=6/126)
# std/transforms.xgdb/trimmomatic.py
#           1,283 100%   30.56kB/s    0:00:00 (xfr#97, to-chk=5/126)
# std/transforms.xgdb/_metadata/
# std/transforms.xgdb/_metadata/index.yml
#           1,275 100%   30.37kB/s    0:00:00 (xfr#98, to-chk=3/126)
# std/transforms.xgdb/_metadata/types/
# std/transforms.xgdb/_metadata/types/std.yml
#           7,408 100%  176.45kB/s    0:00:00 (xfr#99, to-chk=1/126)
# std/transforms.xgdb/_metadata/types/transforms.yml
#             192 100%    4.57kB/s    0:00:00 (xfr#100, to-chk=0/126)
# sending incremental file list

# %%
retry = 0
(2**retry)+0.1
# Out:
# 1.1

# %%
# import logging

# logger = logging.getLogger()
# logger.setLevel(logging.DEBUG)
# logger.handlers.clear()
# logger.addHandler(logging.StreamHandler())
# logger.addHandler(logging.FileHandler(f"./x.log"))

# logger.info("asdf")
# # logger.handlers[0].flush()

# %%
# with LiveShell() as shell:
#     shell.RegisterOnOut(lambda x: print(x))
#     shell.RegisterOnErr(lambda x: print(f"E: {x}"))
#     shell.Exec(f"sleep 300 && echo asdf")

# %%
# with LiveShell() as shell:
#     shell.RegisterOnOut(lambda x: print(x))
#     shell.RegisterOnErr(lambda x: print(f"E: {x}"))
#     shell.Exec(
#         f"""
#         cd /home/tony/workspace/tools/Metasmith/main/local_mock/cache/ws1/run_container
#         apptainer run --no-home --workdir /ws \
#             --bind ./:/ws,.msm:/msm_home \
#             --bind ./:/agent_home \
#             --bind /home/tony/workspace/tools/Metasmith/src/metasmith:/opt/conda/envs/metasmith_env/lib/python3.12/site-packages/metasmith \
#             /home/tony/workspace/tools/Metasmith/metasmith.sif nextflow

#         apptainer run -B ./:/ws
#         cd ~/downloads 
#         mkdir x && cd x
#         /home/tony/workspace/metasmith/lib/msm_bootstrap
#         """
#     )
