# %% [markdown]
# check performance of "batch solve" for parallel solutions
#
# issue was Node.AddAsDependency not adding parents
#
# lineage constraint used to guide the dfs

# %%
from pathlib import Path
from dataclasses import dataclass
from metasmith import DataInstanceLibrary, Endpoint, DataTypeLibrary, TransformInstanceLibrary
from metasmith.hashing import KeyGenerator

from local.constants import WORKSPACE_ROOT
from local.utils import LinkifyPath
CACHE = WORKSPACE_ROOT/"main/local_mock/cache"

# %%
TEST_DIR = CACHE/"test_1k_parallel"
TEST_DIR.mkdir(parents=True, exist_ok=True)

types = DataTypeLibrary.Load(WORKSPACE_ROOT/"main/local_mock/prototypes/metagenomics.dev3.yml")
refdb = DataInstanceLibrary.Load(CACHE/"ref.xgdb")

xgdbs: list[DataInstanceLibrary] = []
for i in range(1000):
    xgdb = DataInstanceLibrary(TEST_DIR/f"{i:03}.xgdb")
    _type = types["contigs"].Clone(properties_only=True)
    _type.AddProperty(key="id", value=f"{i}")
    xgdb.ImportDataInstance(WORKSPACE_ROOT/"scratch/test_ws/data/local/example.fna", _type, overwrite=True)
    xgdbs.append(xgdb)

# %%
trlib = TransformInstanceLibrary.Load([
    Path("./transforms/simple_1"),
    # Path("./transforms/dupe_test"),
])
for k, v in trlib:
    print(k.name, type(v))
# Out:
# diamond.py <class 'metasmith.models.libraries.TransformInstance'>
# pprodigal.py <class 'metasmith.models.libraries.TransformInstance'>

# %%
from dataclasses import dataclass
from pathlib import Path
from typing import Iterable

from metasmith.models.workflow import WorkflowStep
from metasmith.models.libraries import DataTypeLibrary
from metasmith.models.libraries import DataInstance, DataInstanceLibrary
from metasmith.models.libraries import TransformInstance, TransformInstanceLibrary
from metasmith.models.solver import Endpoint, Dependency, Transform, _solve_by_bounded_dfs

# plan = WorkflowPlan.Generate(
#     given=xgdbs+[refdb],
#     transforms=trlib,
#     # targets=[
#     #     types["orf_annotations"] for i, xgdb in enumerate(xgdbs)
#     # ],
#     targets=[
#         types["orf_annotations"].WithLineage([
#             # xgdb["example.fna"].type,
#         ]) for i, xgdb in enumerate(xgdbs)
#     ],
# )
    
given: Iterable[DataInstanceLibrary]=xgdbs+[refdb]
transforms: TransformInstanceLibrary=trlib
targets: list[Endpoint]=[
    types["orf_annotations"].WithLineage([
        xgdb["example.fna"].type,
    ]) for i, xgdb in enumerate(xgdbs)
]

_given_map: dict[Endpoint, DataInstance] = {}
for lib in given:
    _map = {e.type:e for e in lib.manifest.values()}
    for inst in _map.values():
        inst.source = lib.source/inst.source
    _given_map.update(_map)

_transform_map = {t.model:t for _, t in transforms}

_target_e2d: dict[Endpoint, Dependency] = {}
_target_model = Transform()
for t in targets:
    t.AddAsDependency(_target_model, _target_e2d)

def do():
    return _solve_by_bounded_dfs(
        given=_given_map.keys(),
        target=_target_model,
        transforms=_transform_map.keys(),
        # _debug=True,
    )
# %prun solutions = do()
# solutions = do()

assert len(solutions) > 0, "failed to make plan!"
solution = solutions[0]

_instance_map = _given_map.copy()
steps: list[WorkflowStep] = []
for i, appl in enumerate(solution.dependency_plan):
    tr = _transform_map[appl.transform]
    for e, d in appl.produced.items():
        p = tr.output_signature[d]
        _instance = DataInstance(p, e)
        _instance_map[e] = _instance
    
    step = WorkflowStep(
        order=i+1,
        transform_key=tr.model.key,
        uses=[_instance_map[e] for e in appl.used],
        produces=[_instance_map[e] for e in appl.produced],
        transform=tr,
    )
    steps.append(step)

_sol_produces_d2e = {d:e for e, d in solution.application.used.items()}
_sol_target_instances: list[DataInstance] = []
for e in targets:
    d = _target_e2d[e]
    _appl_e = _sol_produces_d2e[d]
    _inst = _instance_map[_appl_e]
    _sol_target_instances.append(_inst)
    
for step in steps:
    if step.transform._source.name != "diamond.py": continue
    # print([f"{x.type}" for x in step.uses], [f"{x.type}" for x in step.produces], sep="->")
    # print([f"{x.source.name}:{x.type.key}" for x in step.uses], [f"{x.source.name}" for x in step.produces], sep="->")
    # LinkifyPath(step.transform._source)
# Out:
#          34326343 function calls (34308322 primitive calls) in 8.421 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#   6000000    1.753    0.000    4.096    0.000 solver.py:384(<genexpr>)
#   8019025    1.372    0.000    2.207    0.000 solver.py:75(IsA)
#   8019025    0.835    0.000    0.835    0.000 {method 'issubset' of 'set' objects}
#   6020000    0.823    0.000    0.940    0.000 solver.py:192(Iterparents)
#      1003    0.744    0.001    0.756    0.001 solver.py:216(AddProduct)
#   1001000    0.708    0.000    6.195    0.000 solver.py:423(_add_result)
#   1004000    0.630    0.000    4.726    0.000 {built-in method builtins.all}
# 2005/2000    0.491    0.000    7.392    0.004 solver.py:388(_solve_dep)
#   1006002    0.428    0.000    5.154    0.000 solver.py:382(_satisfies_lineage)
#    5002/3    0.152    0.000    0.227    0.076 solver.py:482(_gather)
#   1022023    0.118    0.000    0.118    0.000 {method 'items' of 'dict' objects}
#     13029    0.083    0.000    0.154    0.000 {method 'join' of 'str' objects}
#   1012244    0.080    0.000    0.080    0.000 {built-in method builtins.isinstance}
#   1006008    0.069    0.000    0.069    0.000 solver.py:454(<genexpr>)
#    1002/1    0.040    0.000    7.663    7.663 solver.py:445(_solve_tr)
#      3005    0.013    0.000    0.026    0.000 hashing.py:12(GenerateUID)
#      3000    0.011    0.000    0.012    0.000 {method 'union' of 'set' objects}
#      2001    0.010    0.000    0.042    0.000 solver.py:293(Apply)
# 15000/8000    0.005    0.000    0.014    0.000 solver.py:85(Signature)
#     53011    0.005    0.000    0.005    0.000 solver.py:47(__hash__)
# 10003/9000    0.005    0.000    0.008    0.000 solver.py:87(<genexpr>)
#      3005    0.004    0.000    0.004    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      3005    0.004    0.000    0.010    0.000 fromnumeric.py:69(_wrapreduction)
#      3003    0.004    0.000    0.032    0.000 solver.py:55(__init__)
#      3006    0.004    0.000    0.006    0.000 solver.py:358(_get_producers_of)
#      2000    0.003    0.000    0.026    0.000 solver.py:186(__init__)
# 6009/4003    0.003    0.000    0.011    0.000 {built-in method builtins.sorted}
# 19031/17030    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#     14038    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      3005    0.002    0.000    0.012    0.000 fromnumeric.py:3328(prod)
#      2001    0.002    0.000    0.047    0.000 solver.py:374(_apply)
#      4042    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#      3005    0.001    0.000    0.027    0.000 solver.py:20(NewKey)
#      1003    0.001    0.000    0.013    0.000 solver.py:219(_add_dependency)
#      6000    0.001    0.000    0.002    0.000 solver.py:538(<genexpr>)
#      9001    0.001    0.000    0.001    0.000 solver.py:375(<genexpr>)
#      3004    0.001    0.000    0.028    0.000 solver.py:42(__init__)
#      6000    0.001    0.000    0.001    0.000 solver.py:540(<genexpr>)
#       138    0.001    0.000    0.002    0.000 ipkernel.py:775(_clean_thread_parent_frames)
#         1    0.001    0.001    8.422    8.422 3770002863.py:46(do)
#      1003    0.001    0.000    0.011    0.000 solver.py:178(__init__)
#      1000    0.001    0.000    0.001    0.000 solver.py:50(__eq__)
#       5/1    0.000    0.000    8.422    8.422 {built-in method builtins.exec}
#      3005    0.000    0.000    0.000    0.000 fromnumeric.py:3323(_prod_dispatcher)
#      2281    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1142    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        69    0.000    0.000    0.000    0.000 threading.py:1535(enumerate)
#      1002    0.000    0.000    0.000    0.000 solver.py:456(<genexpr>)
#      2001    0.000    0.000    0.000    0.000 solver.py:336(__len__)
#       552    0.000    0.000    0.000    0.000 threading.py:1198(ident)
#         3    0.000    0.000    0.228    0.076 solver.py:479(_gather_valid_inputs)
#      2001    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.002    0.002 dataclasses.py:921(_process_class)
#      2001    0.000    0.000    0.001    0.000 solver.py:551(<lambda>)
#         2    0.000    0.000    0.003    0.001 base_events.py:1915(_run_once)
#      1000    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    8.411    8.411 solver.py:348(_solve_by_bounded_dfs)
#      1004    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       3/1    0.000    0.000    0.000    0.000 inspect.py:2501(_signature_from_callable)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.__build_class__}
#        18    0.000    0.000    0.000    0.000 dataclasses.py:701(_is_type)
#         2    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         1    0.000    0.000    0.000    0.000 futures.py:313(_set_result_unless_cancelled)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:760(_get_field)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:250(_recursive_repr)
#         1    0.000    0.000    0.000    0.000 inspect.py:3297(__str__)
#         1    0.000    0.000    8.422    8.422 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:568(_init_fn)
#         2    0.000    0.000    0.000    0.000 inspect.py:1832(_shadowed_dict)
#         6    0.000    0.000    0.000    0.000 inspect.py:2830(__str__)
#         1    0.000    0.000    0.000    0.000 solver.py:349(State)
#         1    0.000    0.000    0.000    0.000 inspect.py:2150(_signature_is_builtin)
#        70    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 inspect.py:1845(getattr_static)
#         3    0.000    0.000    0.000    0.000 inspect.py:2030(_signature_get_user_defined_method)
#         1    0.000    0.000    0.000    0.000 inspect.py:2164(_signature_is_functionlike)
#         7    0.000    0.000    0.000    0.000 inspect.py:2743(__init__)
#         3    0.000    0.000    0.000    0.000 dataclasses.py:449(_create_fn)
#         1    0.000    0.000    0.002    0.002 dataclasses.py:1247(dataclass)
#         1    0.000    0.000    0.000    0.000 inspect.py:2397(_signature_from_function)
#         2    0.000    0.000    0.000    0.000 events.py:36(__init__)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:489(_field_init)
#         2    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#        12    0.000    0.000    0.000    0.000 dataclasses.py:697(_is_kw_only)
#         1    0.000    0.000    0.002    0.002 dataclasses.py:1264(wrap)
#        12    0.000    0.000    0.000    0.000 dataclasses.py:691(_is_initvar)
#         2    0.000    0.000    0.000    0.000 inspect.py:176(get_annotations)
#         3    0.000    0.000    0.000    0.000 events.py:86(_run)
#         3    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         6    0.000    0.000    0.000    0.000 base_events.py:733(time)
#        18    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:428(_fields_in_init_order)
#         2    0.000    0.000    0.000    0.000 tasks.py:653(sleep)
#         2    0.000    0.000    0.000    0.000 inspect.py:3029(__init__)
#         1    0.000    0.000    0.000    0.000 iostream.py:127(_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 functools.py:65(wraps)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:404(field)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:661(_cmp_fn)
#         1    0.000    0.000    0.000    0.000 <frozen abc>:146(update_abstractmethods)
#         1    0.000    0.000    0.000    0.000 iostream.py:718(_rotate_buffers)
#        51    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         7    0.000    0.000    0.000    0.000 inspect.py:1463(formatannotation)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 iostream.py:118(_run_event_pipe_gc)
#         1    0.000    0.000    0.000    0.000 iostream.py:616(_flush)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         7    0.000    0.000    0.000    0.000 enum.py:720(__call__)
#        36    0.000    0.000    0.000    0.000 {method 'group' of 're.Match' objects}
#         2    0.000    0.000    0.000    0.000 threading.py:1222(is_alive)
#         1    0.000    0.000    0.000    0.000 events.py:155(cancel)
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 inspect.py:2124(_signature_bound_method)
#         1    0.000    0.000    0.000    0.000 inspect.py:3081(from_callable)
#         1    0.000    0.000    0.000    0.000 base_events.py:742(call_later)
#         1    0.000    0.000    0.000    0.000 solver.py:198(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:754(unwrap)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:864(_set_new_attribute)
#         1    0.000    0.000    0.000    0.000 base_events.py:813(_call_soon)
#         1    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:446(create_future)
#         1    0.000    0.000    0.000    0.000 base_events.py:766(call_at)
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         4    0.000    0.000    0.000    0.000 dataclasses.py:857(_set_qualname)
#         6    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         2    0.000    0.000    0.000    0.000 inspect.py:1806(_check_class)
#         8    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.000    0.000 functools.py:35(update_wrapper)
#        12    0.000    0.000    0.000    0.000 dataclasses.py:683(_is_classvar)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:627(_repr_fn)
#         2    0.000    0.000    0.000    0.000 threading.py:1155(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 dataclasses.py:437(_tuple_str)
#         1    0.000    0.000    0.000    0.000 base_events.py:784(call_soon)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        13    0.000    0.000    0.000    0.000 dataclasses.py:461(<genexpr>)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.repr}
#         1    0.000    0.000    0.000    0.000 inspect.py:3343(signature)
#         8    0.000    0.000    0.000    0.000 inspect.py:3076(<genexpr>)
#         7    0.000    0.000    0.000    0.000 enum.py:1123(__new__)
#         7    0.000    0.000    0.000    0.000 {method '__contains__' of 'frozenset' objects}
#         7    0.000    0.000    0.000    0.000 {method 'isidentifier' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 selector_events.py:750(_process_events)
#         3    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 events.py:111(__init__)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:477(_field_assign)
#        20    0.000    0.000    0.000    0.000 inspect.py:2808(kind)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:549(_init_param)
#         1    0.000    0.000    0.000    0.000 inspect.py:2492(_descriptor_get)
#         6    0.000    0.000    0.000    0.000 dataclasses.py:309(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3097(replace)
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 events.py:72(cancel)
#         3    0.000    0.000    0.000    0.000 inspect.py:302(isclass)
#         7    0.000    0.000    0.000    0.000 dataclasses.py:1142(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         7    0.000    0.000    0.000    0.000 dataclasses.py:432(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#        13    0.000    0.000    0.000    0.000 inspect.py:2796(name)
#         3    0.000    0.000    0.000    0.000 inspect.py:378(isfunction)
#         1    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         4    0.000    0.000    0.000    0.000 base_events.py:2010(get_debug)
#         1    0.000    0.000    0.000    0.000 <string>:1(__create_fn__)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:310(ismethoddescriptor)
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 base_events.py:538(_check_closed)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         6    0.000    0.000    0.000    0.000 inspect.py:2800(default)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 inspect.py:524(isbuiltin)
#         2    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 dataclasses.py:372(__init__)
#         2    0.000    0.000    0.000    0.000 inspect.py:3089(parameters)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.vars}
#         2    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         2    0.000    0.000    0.000    0.000 inspect.py:3093(return_annotation)
#         1    0.000    0.000    0.000    0.000 base_events.py:1910(_timer_handle_cancelled)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:433(<genexpr>)
#         1    0.000    0.000    0.000    0.000 dataclasses.py:879(_hash_set_none)
